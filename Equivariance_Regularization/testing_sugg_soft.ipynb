# %% [markdown]
# Testing a local regularization system where adjacent nodes in the last hidden layer are regularized to have
# similar associated weights

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time
import os
from windows_inhibitor import WindowsInhibitor
import pickle
from groupy.gconv.pytorch_gconv.splitgconv2d import P4MConvZ2, P4MConvP4M, P4ConvZ2, P4ConvP4
from groupy.gconv.pytorch_gconv.pooling import plane_group_spatial_max_pooling
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import logging
logging.basicConfig(level=logging.INFO, filename='testing_sugg_soft.log', 
                    format='%(asctime)s:%(name)s:%(levelname)s:%(message)s')
logging.info('Starting New Test')

# %%
indices = list(range(60_000))
# np.random.shuffle(indices)
train_indices = indices[:10_000]
valid_indices = indices[50_000:]
logging.info(f'Train length: {len(train_indices)}')
logging.info(f'Valid length: {len(valid_indices)}')

# %%
AUGMENT = False
if AUGMENT:
    train_transform = transforms.Compose([
    # transforms.RandomHorizontalFlip(),
    # transforms.Pad(2),
    transforms.RandomAffine(15, translate=(0.1, 0.1), scale=(0.95, 1.05)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])
    
    valid_transform = transforms.Compose([
        # transforms.Pad(2),
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
else:
    train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
    
logging.info(f'train_transform: {repr(train_transform)}')
logging.info(f'valid_transform: {repr(valid_transform)}')
    
translate_transform = transforms.Compose([
    transforms.RandomAffine(0, translate=(0.2, 0.2), scale=(1, 1)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])

rotate_transform = transforms.Compose([
    transforms.RandomAffine(30),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])

train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

train_set = torchvision.datasets.MNIST(root='./data', train=True,
                                      download=True, transform=train_transform)
valid_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=valid_transform)
translate_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=translate_transform)
rotation_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=rotate_transform)
# trainset, validation_set = random_split(full_train_set,[50_000,10_000])
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=20,
#                                           shuffle=True, num_workers=2)
# testset = torchvision.datasets.MNIST(root='./data', train=False,
#                                      download=True, transform=transforms.ToTensor())
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal',
               'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
USE_CUDA = True
# Regularization hyper-parameters
BASE = 1
LAMBDA = 30
DECAY = 0.1 ** 6
logging.info(f'(Regularization) BASE = {BASE}, LAMBDA = {LAMBDA}, DECAY = {DECAY}')
# Optimization hyper-parameters
LR = 0.01
LR_BASE = 0.95
MOMENTUM = 0.5
logging.info(f'LR = {LR}, LR_BASE = {LR_BASE}, MOMENTUM = {MOMENTUM}')
# testloader = torch.utils.data.DataLoader(testset, batch_size=1024,
#                                          shuffle=False, num_workers=2)

trainloader = torch.utils.data.DataLoader(train_set, batch_size=20, sampler=train_sampler,
                                          shuffle=False, num_workers=2, pin_memory=USE_CUDA)
validation_loader = torch.utils.data.DataLoader(valid_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)
translate_loader = torch.utils.data.DataLoader(translate_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)
rotation_loader = torch.utils.data.DataLoader(rotation_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)
logging.info(f'Trainloader = {repr(trainloader)}')

# %%
# functions to show an image


def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
# dataiter = iter(trainloader)
# images, labels = dataiter.next()
# 
# # show images
# imshow(torchvision.utils.make_grid(images))

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = P4ConvZ2(1, 16, kernel_size=3)
        self.conv2 = P4ConvP4(16, 32, kernel_size=3)
        # self.conv3 = P4MConvP4M(20, 20, kernel_size=5, padding=2, stride=2)
        self.conv4 = P4ConvP4(32, 64, kernel_size=3)
        self.conv5 = P4ConvP4(64, 128, kernel_size=3)
        # self.conv6 = P4MConvP4M(40, 40, kernel_size=5, padding=2, stride=2)
        self.fc1 = nn.Linear(4 * 4 * 128 * 4, 10)
        # self.prior_mean = nn.Parameter(torch.zeros([128, 10, 4, 1, 1], requires_grad=True))
        # self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        # x = F.relu(self.conv3(x))
        x = plane_group_spatial_max_pooling(x, 2, 2)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        # x = F.relu(self.conv6(x))
        x = plane_group_spatial_max_pooling(x, 2, 2)
        # print(x.shape)
        x = x.view(x.size()[0], -1)
        x = self.fc1(x)
        # x = F.dropout(x, training=self.training, p=0.4)
        # x = self.fc2(x)
        return x

# %%
def run():
    net = Net()
    # from my_nets import DoubleEquivFat
    # net = DoubleEquivFat()
    train_error_list = []
    test_error_list = []
    true_epoch = 0
    total_time = 0
    torch.cuda.empty_cache()
    logging.info(repr(net))
    
    # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    # net.to(device)
    # trainloader = torch.utils.data.DataLoader(train_set, batch_size=20, sampler=train_sampler,
    #                                           shuffle=False, num_workers=2, pin_memory=USE_CUDA)
    criterion = nn.CrossEntropyLoss()
    equivariant_loss = nn.MSELoss()
    logging.info(f'equivariant loss function: {repr(equivariant_loss)}')
    # weight_penalty = nn.MSELoss()
    
    # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    device = torch.device("cuda:0" if USE_CUDA else "cpu")
    net.to(device)
    learned_train_set = False
    vert_convolver = torch.tensor([[1], [-1]], dtype=torch.float32, requires_grad=False, device=device)
    horiz_convolver = torch.tensor([[1, -1]], dtype=torch.float32, requires_grad=False, device=device)
    vert_convolver, horiz_convolver = vert_convolver.view([1, 1, 1, 2, 1]), horiz_convolver.view([1, 1, 1, 1, 2])
    # net.gconv1.flat_indices = net.gconv1.flat_indices.cuda()
    for epoch in range(80):  # loop over the dataset multiple times
        start_time = time.time()
        # little_lambda = LAMBDA * BASE ** true_epoch
        optimizer = optim.SGD(net.parameters(), lr=LR * LR_BASE ** true_epoch, momentum=MOMENTUM, weight_decay=DECAY)
        little_lambda = (1 / (len(trainloader) * 2)) * LAMBDA * BASE ** true_epoch
        true_epoch += 1
        logging.info(f'Starting epoch {true_epoch}')
        running_loss = 0.0
        true_train_total = 0.0
        correct_train_total = 0.0
        correct_train = 0.0
        total_train = 0.0
        total_equi_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # zero the parameter gradients
            optimizer.zero_grad()
    
            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            
            nonequiv_weights1 = net.fc1.weight
            nonequiv_weights1 = nonequiv_weights1.view(1, 1, 128 * 10 * 4, 4, 4)
            # prime_weights = net.prior_mean.expand(128, 10, 4, 4, 4)
            # if i % 500 == 499:
            #     print(nonequiv_weights1[0,0,:,:,:])
            #     print(prime_weights[0,0,:,:,:])
            if little_lambda:
                discrepency =  torch.sum(F.conv3d(nonequiv_weights1, vert_convolver) ** 2) +\
                    torch.sum(F.conv3d(nonequiv_weights1, horiz_convolver) ** 2)
                loss += little_lambda * discrepency
                total_equi_loss += little_lambda * discrepency.detach()
                # if true_epoch > 3:
                #     print(little_lambda * equivariant_loss(nonequiv_weights1, prime_weights))
            # if DECAY:
            #     loss += DECAY * weight_penalty(net.fc2.weight,prime_weights.new_zeros([1],requires_grad=False))  

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            true_train_total += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            correct_train_total += (predicted == labels).sum().item()

            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 500 == 499:  # print every 500 mini-batches
                msg = f'[{true_epoch}, {i + 1}] loss: {running_loss / total_train:.4f}, ' \
                      f'e-loss: {total_equi_loss / total_train:.4f}, ' \
                      f'Correct Rate: {100 * correct_train / total_train:.2f}%'
                print(msg)
                
                # if running_loss / 100  < 0.005:
                #     break
                running_loss = 0.0
                correct_train = 0.0
                total_train = 0.0
                total_equi_loss = 0.0
        train_error_list.append(100*correct_train_total / true_train_total)
        print(f"Correctness on training epoch: {100*correct_train_total / true_train_total:.2f}%")
        logging.info(f"Correctness on training epoch: {100*correct_train_total / true_train_total:.2f}%")
        correct = 0
        total = 0
        with torch.no_grad():
            for val_data in validation_loader:
                images, labels = val_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 validation images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 validation images: {100 * correct / total:.2f}%')
            for trans_data in translate_loader:
                images, labels = trans_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 translated images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 translated images: {100 * correct / total:.2f}%')
            for rotate_data in rotation_loader:
                images, labels = rotate_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 rotated images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 rotated images: {100 * correct / total:.2f}%')
        total_time += time.time() - start_time
        print(f'Finished epoch, cumulative time: {total_time}s')
        if correct_train_total == true_train_total:
            if not learned_train_set:
                learned_train_set = True
            else:
                break
    print("Finished")
    logging.info("Finished")

# %%
with WindowsInhibitor():
    logging.info("-----------------------Starting Testing--------------------------------")
    for i in range(6):
        logging.info(f'-------------------------Starting test {i+1}----------------------------')
        run()
    logging.info(f'-------------------------Testing Finished----------------------------')
# Out:
# Preventing Windows from going to sleep
# [1, 500] loss: 0.0218, e-loss: 0.0072, Correct Rate: 90.79%
# Correctness on training epoch: 90.79%
# Accuracy of the network on the 10000 validation images: 97.05%
# Accuracy of the network on the 10000 translated images: 72.23%
# Accuracy of the network on the 10000 rotated images: 78.22%
# Finished epoch, cumulative time: 28.3751163482666s
# [2, 500] loss: 0.0088, e-loss: 0.0037, Correct Rate: 97.03%
# Correctness on training epoch: 97.03%
# Accuracy of the network on the 10000 validation images: 97.72%
# Accuracy of the network on the 10000 translated images: 76.27%
# Accuracy of the network on the 10000 rotated images: 81.38%
# Finished epoch, cumulative time: 56.91287541389465s
# [3, 500] loss: 0.0066, e-loss: 0.0030, Correct Rate: 97.88%
# Correctness on training epoch: 97.88%
# Accuracy of the network on the 10000 validation images: 96.83%
# Accuracy of the network on the 10000 translated images: 77.58%
# Accuracy of the network on the 10000 rotated images: 81.84%
# Finished epoch, cumulative time: 85.69445085525513s
# [4, 500] loss: 0.0055, e-loss: 0.0027, Correct Rate: 98.21%
# Correctness on training epoch: 98.21%
# Accuracy of the network on the 10000 validation images: 97.65%
# Accuracy of the network on the 10000 translated images: 81.02%
# Accuracy of the network on the 10000 rotated images: 84.59%
# Finished epoch, cumulative time: 114.25468420982361s
# [5, 500] loss: 0.0050, e-loss: 0.0025, Correct Rate: 98.42%
# Correctness on training epoch: 98.42%
# Accuracy of the network on the 10000 validation images: 97.75%
# Accuracy of the network on the 10000 translated images: 82.67%
# Accuracy of the network on the 10000 rotated images: 85.69%
# Finished epoch, cumulative time: 142.87876963615417s
# [6, 500] loss: 0.0042, e-loss: 0.0022, Correct Rate: 98.69%
# Correctness on training epoch: 98.69%
# Accuracy of the network on the 10000 validation images: 98.11%
# Accuracy of the network on the 10000 translated images: 83.17%
# Accuracy of the network on the 10000 rotated images: 86.31%
# Finished epoch, cumulative time: 170.81920433044434s
# [7, 500] loss: 0.0038, e-loss: 0.0020, Correct Rate: 98.81%
# Correctness on training epoch: 98.81%
# Accuracy of the network on the 10000 validation images: 98.05%
# Accuracy of the network on the 10000 translated images: 83.42%
# Accuracy of the network on the 10000 rotated images: 86.53%
# Finished epoch, cumulative time: 199.04156303405762s
# [8, 500] loss: 0.0035, e-loss: 0.0019, Correct Rate: 98.97%
# Correctness on training epoch: 98.97%
# Accuracy of the network on the 10000 validation images: 97.37%
# Accuracy of the network on the 10000 translated images: 84.89%
# Accuracy of the network on the 10000 rotated images: 87.01%
# Finished epoch, cumulative time: 227.32596373558044s
# [9, 500] loss: 0.0032, e-loss: 0.0017, Correct Rate: 99.07%
# Correctness on training epoch: 99.07%
# Accuracy of the network on the 10000 validation images: 98.80%
# Accuracy of the network on the 10000 translated images: 86.27%
# Accuracy of the network on the 10000 rotated images: 88.85%
# Finished epoch, cumulative time: 255.51259350776672s
# [10, 500] loss: 0.0026, e-loss: 0.0015, Correct Rate: 99.28%
# Correctness on training epoch: 99.28%
# Accuracy of the network on the 10000 validation images: 98.36%
# Accuracy of the network on the 10000 translated images: 85.55%
# Accuracy of the network on the 10000 rotated images: 87.87%
# Finished epoch, cumulative time: 284.0434126853943s
# [11, 500] loss: 0.0026, e-loss: 0.0014, Correct Rate: 99.37%
# Correctness on training epoch: 99.37%
# Accuracy of the network on the 10000 validation images: 98.64%
# Accuracy of the network on the 10000 translated images: 88.11%
# Accuracy of the network on the 10000 rotated images: 89.97%
# Finished epoch, cumulative time: 313.2323534488678s
# [12, 500] loss: 0.0020, e-loss: 0.0012, Correct Rate: 99.52%
# Correctness on training epoch: 99.52%
# Accuracy of the network on the 10000 validation images: 98.76%
# Accuracy of the network on the 10000 translated images: 87.17%
# Accuracy of the network on the 10000 rotated images: 89.24%
# Finished epoch, cumulative time: 341.4349331855774s
# [13, 500] loss: 0.0023, e-loss: 0.0012, Correct Rate: 99.31%
# Correctness on training epoch: 99.31%
# Accuracy of the network on the 10000 validation images: 98.59%
# Accuracy of the network on the 10000 translated images: 86.08%
# Accuracy of the network on the 10000 rotated images: 88.60%
# Finished epoch, cumulative time: 369.5738184452057s
# [14, 500] loss: 0.0016, e-loss: 0.0010, Correct Rate: 99.70%
# Correctness on training epoch: 99.70%
# Accuracy of the network on the 10000 validation images: 98.72%
# Accuracy of the network on the 10000 translated images: 88.28%
# Accuracy of the network on the 10000 rotated images: 90.12%
# Finished epoch, cumulative time: 397.81628942489624s
# [15, 500] loss: 0.0013, e-loss: 0.0008, Correct Rate: 99.76%
# Correctness on training epoch: 99.76%
# Accuracy of the network on the 10000 validation images: 97.07%
# Accuracy of the network on the 10000 translated images: 85.06%
# Accuracy of the network on the 10000 rotated images: 87.16%
# Finished epoch, cumulative time: 425.9032018184662s
# [16, 500] loss: 0.0012, e-loss: 0.0008, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.91%
# Accuracy of the network on the 10000 translated images: 89.00%
# Accuracy of the network on the 10000 rotated images: 90.71%
# Finished epoch, cumulative time: 454.31452679634094s
# [17, 500] loss: 0.0009, e-loss: 0.0006, Correct Rate: 99.86%
# Correctness on training epoch: 99.86%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 88.83%
# Accuracy of the network on the 10000 rotated images: 90.50%
# Finished epoch, cumulative time: 482.52903747558594s
# [18, 500] loss: 0.0011, e-loss: 0.0006, Correct Rate: 99.72%
# Correctness on training epoch: 99.72%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 88.79%
# Accuracy of the network on the 10000 rotated images: 90.42%
# Finished epoch, cumulative time: 510.657945394516s
# [19, 500] loss: 0.0011, e-loss: 0.0007, Correct Rate: 99.74%
# Correctness on training epoch: 99.74%
# Accuracy of the network on the 10000 validation images: 98.73%
# Accuracy of the network on the 10000 translated images: 89.15%
# Accuracy of the network on the 10000 rotated images: 90.52%
# Finished epoch, cumulative time: 539.070540189743s
# [20, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.93%
# Correctness on training epoch: 99.93%
# Accuracy of the network on the 10000 validation images: 98.89%
# Accuracy of the network on the 10000 translated images: 89.92%
# Accuracy of the network on the 10000 rotated images: 91.41%
# Finished epoch, cumulative time: 567.4319462776184s
# [21, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 99.98%
# Correctness on training epoch: 99.98%
# Accuracy of the network on the 10000 validation images: 98.83%
# Accuracy of the network on the 10000 translated images: 89.97%
# Accuracy of the network on the 10000 rotated images: 91.19%
# Finished epoch, cumulative time: 595.4380948543549s
# [22, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 99.96%
# Correctness on training epoch: 99.96%
# Accuracy of the network on the 10000 validation images: 98.89%
# Accuracy of the network on the 10000 translated images: 90.17%
# Accuracy of the network on the 10000 rotated images: 91.38%
# Finished epoch, cumulative time: 623.6466898918152s
# [23, 500] loss: 0.0003, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.84%
# Accuracy of the network on the 10000 translated images: 90.36%
# Accuracy of the network on the 10000 rotated images: 91.37%
# Finished epoch, cumulative time: 652.0699214935303s
# [24, 500] loss: 0.0003, e-loss: 0.0002, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.81%
# Accuracy of the network on the 10000 translated images: 90.49%
# Accuracy of the network on the 10000 rotated images: 91.58%
# Finished epoch, cumulative time: 680.4262838363647s
# Finished
# [1, 500] loss: 0.0215, e-loss: 0.0071, Correct Rate: 91.25%
# Correctness on training epoch: 91.25%
# Accuracy of the network on the 10000 validation images: 97.14%
# Accuracy of the network on the 10000 translated images: 72.85%
# Accuracy of the network on the 10000 rotated images: 78.59%
# Finished epoch, cumulative time: 26.580686569213867s
# [2, 500] loss: 0.0085, e-loss: 0.0037, Correct Rate: 97.14%
# Correctness on training epoch: 97.14%
# Accuracy of the network on the 10000 validation images: 97.65%
# Accuracy of the network on the 10000 translated images: 76.91%
# Accuracy of the network on the 10000 rotated images: 81.52%
# Finished epoch, cumulative time: 53.29893469810486s
# [3, 500] loss: 0.0066, e-loss: 0.0030, Correct Rate: 97.75%
# Correctness on training epoch: 97.75%
# Accuracy of the network on the 10000 validation images: 97.68%
# Accuracy of the network on the 10000 translated images: 78.22%
# Accuracy of the network on the 10000 rotated images: 82.78%
# Finished epoch, cumulative time: 80.18903708457947s
# [4, 500] loss: 0.0057, e-loss: 0.0027, Correct Rate: 98.19%
# Correctness on training epoch: 98.19%
# Accuracy of the network on the 10000 validation images: 98.11%
# Accuracy of the network on the 10000 translated images: 80.54%
# Accuracy of the network on the 10000 rotated images: 84.63%
# Finished epoch, cumulative time: 107.18752956390381s
# [5, 500] loss: 0.0048, e-loss: 0.0024, Correct Rate: 98.60%
# Correctness on training epoch: 98.60%
# Accuracy of the network on the 10000 validation images: 98.32%
# Accuracy of the network on the 10000 translated images: 84.23%
# Accuracy of the network on the 10000 rotated images: 87.36%
# Finished epoch, cumulative time: 133.87085604667664s
# [6, 500] loss: 0.0044, e-loss: 0.0022, Correct Rate: 98.70%
# Correctness on training epoch: 98.70%
# Accuracy of the network on the 10000 validation images: 97.66%
# Accuracy of the network on the 10000 translated images: 83.84%
# Accuracy of the network on the 10000 rotated images: 86.89%
# Finished epoch, cumulative time: 160.54651832580566s
# [7, 500] loss: 0.0038, e-loss: 0.0020, Correct Rate: 98.86%
# Correctness on training epoch: 98.86%
# Accuracy of the network on the 10000 validation images: 98.50%
# Accuracy of the network on the 10000 translated images: 84.64%
# Accuracy of the network on the 10000 rotated images: 87.62%
# Finished epoch, cumulative time: 187.5723853111267s
# [8, 500] loss: 0.0035, e-loss: 0.0018, Correct Rate: 98.96%
# Correctness on training epoch: 98.96%
# Accuracy of the network on the 10000 validation images: 98.26%
# Accuracy of the network on the 10000 translated images: 84.85%
# Accuracy of the network on the 10000 rotated images: 87.46%
# Finished epoch, cumulative time: 214.3718502521515s
# [9, 500] loss: 0.0030, e-loss: 0.0017, Correct Rate: 99.23%
# Correctness on training epoch: 99.23%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 86.53%
# Accuracy of the network on the 10000 rotated images: 89.03%
# Finished epoch, cumulative time: 241.09178161621094s
# [10, 500] loss: 0.0025, e-loss: 0.0014, Correct Rate: 99.42%
# Correctness on training epoch: 99.42%
# Accuracy of the network on the 10000 validation images: 98.07%
# Accuracy of the network on the 10000 translated images: 85.11%
# Accuracy of the network on the 10000 rotated images: 87.67%
# Finished epoch, cumulative time: 267.97008633613586s
# [11, 500] loss: 0.0024, e-loss: 0.0013, Correct Rate: 99.36%
# Correctness on training epoch: 99.36%
# Accuracy of the network on the 10000 validation images: 98.50%
# Accuracy of the network on the 10000 translated images: 87.68%
# Accuracy of the network on the 10000 rotated images: 89.46%
# Finished epoch, cumulative time: 297.35065269470215s
# [12, 500] loss: 0.0024, e-loss: 0.0014, Correct Rate: 99.24%
# Correctness on training epoch: 99.24%
# Accuracy of the network on the 10000 validation images: 97.63%
# Accuracy of the network on the 10000 translated images: 87.07%
# Accuracy of the network on the 10000 rotated images: 88.67%
# Finished epoch, cumulative time: 327.0601706504822s
# [13, 500] loss: 0.0019, e-loss: 0.0011, Correct Rate: 99.54%
# Correctness on training epoch: 99.54%
# Accuracy of the network on the 10000 validation images: 98.56%
# Accuracy of the network on the 10000 translated images: 88.55%
# Accuracy of the network on the 10000 rotated images: 90.13%
# Finished epoch, cumulative time: 355.9300436973572s
# [14, 500] loss: 0.0015, e-loss: 0.0010, Correct Rate: 99.71%
# Correctness on training epoch: 99.71%
# Accuracy of the network on the 10000 validation images: 98.72%
# Accuracy of the network on the 10000 translated images: 89.46%
# Accuracy of the network on the 10000 rotated images: 90.90%
# Finished epoch, cumulative time: 384.5666329860687s
# [15, 500] loss: 0.0013, e-loss: 0.0009, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.47%
# Accuracy of the network on the 10000 translated images: 88.68%
# Accuracy of the network on the 10000 rotated images: 89.94%
# Finished epoch, cumulative time: 413.08541774749756s
# [16, 500] loss: 0.0019, e-loss: 0.0010, Correct Rate: 99.32%
# Correctness on training epoch: 99.32%
# Accuracy of the network on the 10000 validation images: 96.20%
# Accuracy of the network on the 10000 translated images: 86.17%
# Accuracy of the network on the 10000 rotated images: 86.86%
# Finished epoch, cumulative time: 441.11979365348816s
# [17, 500] loss: 0.0013, e-loss: 0.0009, Correct Rate: 99.77%
# Correctness on training epoch: 99.77%
# Accuracy of the network on the 10000 validation images: 98.69%
# Accuracy of the network on the 10000 translated images: 89.86%
# Accuracy of the network on the 10000 rotated images: 90.88%
# Finished epoch, cumulative time: 469.4029793739319s
# [18, 500] loss: 0.0010, e-loss: 0.0007, Correct Rate: 99.81%
# Correctness on training epoch: 99.81%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 89.89%
# Accuracy of the network on the 10000 rotated images: 91.04%
# Finished epoch, cumulative time: 497.7800626754761s
# [19, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.81%
# Correctness on training epoch: 99.81%
# Accuracy of the network on the 10000 validation images: 98.68%
# Accuracy of the network on the 10000 translated images: 89.45%
# Accuracy of the network on the 10000 rotated images: 90.69%
# Finished epoch, cumulative time: 526.1363346576691s
# [20, 500] loss: 0.0008, e-loss: 0.0006, Correct Rate: 99.86%
# Correctness on training epoch: 99.86%
# Accuracy of the network on the 10000 validation images: 98.55%
# Accuracy of the network on the 10000 translated images: 90.08%
# Accuracy of the network on the 10000 rotated images: 90.93%
# Finished epoch, cumulative time: 554.1675674915314s
# [21, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.90%
# Correctness on training epoch: 99.90%
# Accuracy of the network on the 10000 validation images: 98.57%
# Accuracy of the network on the 10000 translated images: 89.03%
# Accuracy of the network on the 10000 rotated images: 90.43%
# Finished epoch, cumulative time: 582.452986240387s
# [22, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 99.97%
# Correctness on training epoch: 99.97%
# Accuracy of the network on the 10000 validation images: 98.88%
# Accuracy of the network on the 10000 translated images: 90.62%
# Accuracy of the network on the 10000 rotated images: 91.61%
# Finished epoch, cumulative time: 610.8079879283905s
# [23, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.97%
# Accuracy of the network on the 10000 translated images: 90.86%
# Accuracy of the network on the 10000 rotated images: 91.82%
# Finished epoch, cumulative time: 639.4409201145172s
# [24, 500] loss: 0.0003, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.84%
# Accuracy of the network on the 10000 translated images: 90.59%
# Accuracy of the network on the 10000 rotated images: 91.32%
# Finished epoch, cumulative time: 667.8819234371185s
# Finished
# [1, 500] loss: 0.0203, e-loss: 0.0070, Correct Rate: 91.80%
# Correctness on training epoch: 91.80%
# Accuracy of the network on the 10000 validation images: 97.27%
# Accuracy of the network on the 10000 translated images: 73.02%
# Accuracy of the network on the 10000 rotated images: 79.04%
# Finished epoch, cumulative time: 28.39914083480835s
# [2, 500] loss: 0.0081, e-loss: 0.0036, Correct Rate: 97.37%
# Correctness on training epoch: 97.37%
# Accuracy of the network on the 10000 validation images: 95.70%
# Accuracy of the network on the 10000 translated images: 75.17%
# Accuracy of the network on the 10000 rotated images: 79.48%
# Finished epoch, cumulative time: 58.746105432510376s
# [3, 500] loss: 0.0062, e-loss: 0.0029, Correct Rate: 97.91%
# Correctness on training epoch: 97.91%
# Accuracy of the network on the 10000 validation images: 98.33%
# Accuracy of the network on the 10000 translated images: 79.92%
# Accuracy of the network on the 10000 rotated images: 84.31%
# Finished epoch, cumulative time: 87.93598771095276s
# [4, 500] loss: 0.0054, e-loss: 0.0026, Correct Rate: 98.32%
# Correctness on training epoch: 98.32%
# Accuracy of the network on the 10000 validation images: 98.21%
# Accuracy of the network on the 10000 translated images: 80.78%
# Accuracy of the network on the 10000 rotated images: 84.38%
# Finished epoch, cumulative time: 116.1445677280426s
# [5, 500] loss: 0.0046, e-loss: 0.0023, Correct Rate: 98.60%
# Correctness on training epoch: 98.60%
# Accuracy of the network on the 10000 validation images: 98.32%
# Accuracy of the network on the 10000 translated images: 83.91%
# Accuracy of the network on the 10000 rotated images: 86.89%
# Finished epoch, cumulative time: 144.27043294906616s
# [6, 500] loss: 0.0040, e-loss: 0.0021, Correct Rate: 98.72%
# Correctness on training epoch: 98.72%
# Accuracy of the network on the 10000 validation images: 97.91%
# Accuracy of the network on the 10000 translated images: 83.63%
# Accuracy of the network on the 10000 rotated images: 86.16%
# Finished epoch, cumulative time: 172.48843121528625s
# [7, 500] loss: 0.0035, e-loss: 0.0019, Correct Rate: 98.99%
# Correctness on training epoch: 98.99%
# Accuracy of the network on the 10000 validation images: 97.58%
# Accuracy of the network on the 10000 translated images: 83.72%
# Accuracy of the network on the 10000 rotated images: 86.06%
# Finished epoch, cumulative time: 200.96320796012878s
# [8, 500] loss: 0.0033, e-loss: 0.0017, Correct Rate: 99.06%
# Correctness on training epoch: 99.06%
# Accuracy of the network on the 10000 validation images: 98.14%
# Accuracy of the network on the 10000 translated images: 83.69%
# Accuracy of the network on the 10000 rotated images: 86.69%
# Finished epoch, cumulative time: 229.49095153808594s
# [9, 500] loss: 0.0030, e-loss: 0.0016, Correct Rate: 99.15%
# Correctness on training epoch: 99.15%
# Accuracy of the network on the 10000 validation images: 98.79%
# Accuracy of the network on the 10000 translated images: 86.06%
# Accuracy of the network on the 10000 rotated images: 88.36%
# Finished epoch, cumulative time: 257.77229499816895s
# [10, 500] loss: 0.0023, e-loss: 0.0014, Correct Rate: 99.45%
# Correctness on training epoch: 99.45%
# Accuracy of the network on the 10000 validation images: 98.22%
# Accuracy of the network on the 10000 translated images: 85.92%
# Accuracy of the network on the 10000 rotated images: 88.16%
# Finished epoch, cumulative time: 284.88541412353516s
# [11, 500] loss: 0.0023, e-loss: 0.0013, Correct Rate: 99.43%
# Correctness on training epoch: 99.43%
# Accuracy of the network on the 10000 validation images: 97.68%
# Accuracy of the network on the 10000 translated images: 85.03%
# Accuracy of the network on the 10000 rotated images: 87.13%
# Finished epoch, cumulative time: 312.2753920555115s
# [12, 500] loss: 0.0023, e-loss: 0.0013, Correct Rate: 99.45%
# Correctness on training epoch: 99.45%
# Accuracy of the network on the 10000 validation images: 98.71%
# Accuracy of the network on the 10000 translated images: 87.62%
# Accuracy of the network on the 10000 rotated images: 89.49%
# Finished epoch, cumulative time: 339.04110312461853s
# [13, 500] loss: 0.0017, e-loss: 0.0010, Correct Rate: 99.71%
# Correctness on training epoch: 99.71%
# Accuracy of the network on the 10000 validation images: 98.87%
# Accuracy of the network on the 10000 translated images: 88.57%
# Accuracy of the network on the 10000 rotated images: 90.37%
# Finished epoch, cumulative time: 365.8314583301544s
# [14, 500] loss: 0.0017, e-loss: 0.0009, Correct Rate: 99.50%
# Correctness on training epoch: 99.50%
# Accuracy of the network on the 10000 validation images: 98.76%
# Accuracy of the network on the 10000 translated images: 89.16%
# Accuracy of the network on the 10000 rotated images: 90.71%
# Finished epoch, cumulative time: 392.67890429496765s
# [15, 500] loss: 0.0012, e-loss: 0.0008, Correct Rate: 99.78%
# Correctness on training epoch: 99.78%
# Accuracy of the network on the 10000 validation images: 98.56%
# Accuracy of the network on the 10000 translated images: 88.91%
# Accuracy of the network on the 10000 rotated images: 90.28%
# Finished epoch, cumulative time: 419.5081663131714s
# [16, 500] loss: 0.0013, e-loss: 0.0007, Correct Rate: 99.71%
# Correctness on training epoch: 99.71%
# Accuracy of the network on the 10000 validation images: 98.31%
# Accuracy of the network on the 10000 translated images: 88.06%
# Accuracy of the network on the 10000 rotated images: 89.72%
# Finished epoch, cumulative time: 446.4162423610687s
# [17, 500] loss: 0.0013, e-loss: 0.0008, Correct Rate: 99.69%
# Correctness on training epoch: 99.69%
# Accuracy of the network on the 10000 validation images: 98.58%
# Accuracy of the network on the 10000 translated images: 89.20%
# Accuracy of the network on the 10000 rotated images: 90.43%
# Finished epoch, cumulative time: 473.29653000831604s
# [18, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.79%
# Correctness on training epoch: 99.79%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 89.39%
# Accuracy of the network on the 10000 rotated images: 90.52%
# Finished epoch, cumulative time: 500.14088916778564s
# [19, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.89%
# Correctness on training epoch: 99.89%
# Accuracy of the network on the 10000 validation images: 98.59%
# Accuracy of the network on the 10000 translated images: 88.98%
# Accuracy of the network on the 10000 rotated images: 90.48%
# Finished epoch, cumulative time: 527.1589665412903s
# [20, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.86%
# Accuracy of the network on the 10000 translated images: 90.31%
# Accuracy of the network on the 10000 rotated images: 91.76%
# Finished epoch, cumulative time: 554.239527463913s
# [21, 500] loss: 0.0006, e-loss: 0.0004, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 90.12%
# Accuracy of the network on the 10000 rotated images: 90.89%
# Finished epoch, cumulative time: 580.9286143779755s
# [22, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.85%
# Correctness on training epoch: 99.85%
# Accuracy of the network on the 10000 validation images: 98.77%
# Accuracy of the network on the 10000 translated images: 89.53%
# Accuracy of the network on the 10000 rotated images: 90.73%
# Finished epoch, cumulative time: 607.7126877307892s
# [23, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.91%
# Accuracy of the network on the 10000 translated images: 90.08%
# Accuracy of the network on the 10000 rotated images: 91.34%
# Finished epoch, cumulative time: 637.7502267360687s
# [24, 500] loss: 0.0003, e-loss: 0.0003, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 89.95%
# Accuracy of the network on the 10000 rotated images: 91.10%
# Finished epoch, cumulative time: 669.4539933204651s
# [25, 500] loss: 0.0007, e-loss: 0.0003, Correct Rate: 99.74%
# Correctness on training epoch: 99.74%
# Accuracy of the network on the 10000 validation images: 98.59%
# Accuracy of the network on the 10000 translated images: 89.78%
# Accuracy of the network on the 10000 rotated images: 90.70%
# Finished epoch, cumulative time: 700.4930031299591s
# [26, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.92%
# Accuracy of the network on the 10000 translated images: 90.47%
# Accuracy of the network on the 10000 rotated images: 91.28%
# Finished epoch, cumulative time: 730.7331442832947s
# Finished
# [1, 500] loss: 0.0196, e-loss: 0.0070, Correct Rate: 92.28%
# Correctness on training epoch: 92.28%
# Accuracy of the network on the 10000 validation images: 97.49%
# Accuracy of the network on the 10000 translated images: 74.03%
# Accuracy of the network on the 10000 rotated images: 79.78%
# Finished epoch, cumulative time: 30.00395178794861s
# [2, 500] loss: 0.0081, e-loss: 0.0034, Correct Rate: 97.16%
# Correctness on training epoch: 97.16%
# Accuracy of the network on the 10000 validation images: 97.78%
# Accuracy of the network on the 10000 translated images: 78.39%
# Accuracy of the network on the 10000 rotated images: 82.99%
# Finished epoch, cumulative time: 59.196035385131836s
# [3, 500] loss: 0.0062, e-loss: 0.0028, Correct Rate: 97.98%
# Correctness on training epoch: 97.98%
# Accuracy of the network on the 10000 validation images: 98.09%
# Accuracy of the network on the 10000 translated images: 81.39%
# Accuracy of the network on the 10000 rotated images: 84.99%
# Finished epoch, cumulative time: 90.21468877792358s
# [4, 500] loss: 0.0052, e-loss: 0.0025, Correct Rate: 98.42%
# Correctness on training epoch: 98.42%
# Accuracy of the network on the 10000 validation images: 98.13%
# Accuracy of the network on the 10000 translated images: 82.75%
# Accuracy of the network on the 10000 rotated images: 86.10%
# Finished epoch, cumulative time: 119.32768487930298s
# [5, 500] loss: 0.0043, e-loss: 0.0022, Correct Rate: 98.74%
# Correctness on training epoch: 98.74%
# Accuracy of the network on the 10000 validation images: 98.81%
# Accuracy of the network on the 10000 translated images: 84.68%
# Accuracy of the network on the 10000 rotated images: 87.66%
# Finished epoch, cumulative time: 147.33087348937988s
# [6, 500] loss: 0.0039, e-loss: 0.0019, Correct Rate: 98.82%
# Correctness on training epoch: 98.82%
# Accuracy of the network on the 10000 validation images: 98.13%
# Accuracy of the network on the 10000 translated images: 85.42%
# Accuracy of the network on the 10000 rotated images: 87.72%
# Finished epoch, cumulative time: 174.8383116722107s
# [7, 500] loss: 0.0035, e-loss: 0.0018, Correct Rate: 98.95%
# Correctness on training epoch: 98.95%
# Accuracy of the network on the 10000 validation images: 98.32%
# Accuracy of the network on the 10000 translated images: 85.64%
# Accuracy of the network on the 10000 rotated images: 88.17%
# Finished epoch, cumulative time: 202.31487274169922s
# [8, 500] loss: 0.0030, e-loss: 0.0016, Correct Rate: 99.13%
# Correctness on training epoch: 99.13%
# Accuracy of the network on the 10000 validation images: 98.61%
# Accuracy of the network on the 10000 translated images: 87.36%
# Accuracy of the network on the 10000 rotated images: 89.23%
# Finished epoch, cumulative time: 229.52727246284485s
# [9, 500] loss: 0.0027, e-loss: 0.0015, Correct Rate: 99.26%
# Correctness on training epoch: 99.26%
# Accuracy of the network on the 10000 validation images: 98.34%
# Accuracy of the network on the 10000 translated images: 87.39%
# Accuracy of the network on the 10000 rotated images: 89.37%
# Finished epoch, cumulative time: 256.8085412979126s
# [10, 500] loss: 0.0023, e-loss: 0.0013, Correct Rate: 99.36%
# Correctness on training epoch: 99.36%
# Accuracy of the network on the 10000 validation images: 98.81%
# Accuracy of the network on the 10000 translated images: 87.45%
# Accuracy of the network on the 10000 rotated images: 89.65%
# Finished epoch, cumulative time: 284.1256742477417s
# [11, 500] loss: 0.0022, e-loss: 0.0013, Correct Rate: 99.39%
# Correctness on training epoch: 99.39%
# Accuracy of the network on the 10000 validation images: 98.24%
# Accuracy of the network on the 10000 translated images: 87.92%
# Accuracy of the network on the 10000 rotated images: 89.45%
# Finished epoch, cumulative time: 311.24422216415405s
# [12, 500] loss: 0.0019, e-loss: 0.0011, Correct Rate: 99.53%
# Correctness on training epoch: 99.53%
# Accuracy of the network on the 10000 validation images: 98.41%
# Accuracy of the network on the 10000 translated images: 87.45%
# Accuracy of the network on the 10000 rotated images: 89.44%
# Finished epoch, cumulative time: 338.4006814956665s
# [13, 500] loss: 0.0019, e-loss: 0.0011, Correct Rate: 99.42%
# Correctness on training epoch: 99.42%
# Accuracy of the network on the 10000 validation images: 98.65%
# Accuracy of the network on the 10000 translated images: 89.15%
# Accuracy of the network on the 10000 rotated images: 90.58%
# Finished epoch, cumulative time: 366.48269724845886s
# [14, 500] loss: 0.0014, e-loss: 0.0009, Correct Rate: 99.76%
# Correctness on training epoch: 99.76%
# Accuracy of the network on the 10000 validation images: 98.88%
# Accuracy of the network on the 10000 translated images: 89.94%
# Accuracy of the network on the 10000 rotated images: 91.32%
# Finished epoch, cumulative time: 394.0022358894348s
# [15, 500] loss: 0.0011, e-loss: 0.0007, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 99.04%
# Accuracy of the network on the 10000 translated images: 90.08%
# Accuracy of the network on the 10000 rotated images: 91.56%
# Finished epoch, cumulative time: 421.2783372402191s
# [16, 500] loss: 0.0011, e-loss: 0.0007, Correct Rate: 99.74%
# Correctness on training epoch: 99.74%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 90.19%
# Accuracy of the network on the 10000 rotated images: 91.44%
# Finished epoch, cumulative time: 448.4718108177185s
# [17, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.86%
# Correctness on training epoch: 99.86%
# Accuracy of the network on the 10000 validation images: 98.37%
# Accuracy of the network on the 10000 translated images: 89.89%
# Accuracy of the network on the 10000 rotated images: 90.43%
# Finished epoch, cumulative time: 475.9953737258911s
# [18, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.83%
# Correctness on training epoch: 99.83%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 90.00%
# Accuracy of the network on the 10000 rotated images: 91.22%
# Finished epoch, cumulative time: 503.4598889350891s
# [19, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.83%
# Correctness on training epoch: 99.83%
# Accuracy of the network on the 10000 validation images: 98.19%
# Accuracy of the network on the 10000 translated images: 88.50%
# Accuracy of the network on the 10000 rotated images: 89.44%
# Finished epoch, cumulative time: 530.8178117275238s
# [20, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.88%
# Accuracy of the network on the 10000 translated images: 90.61%
# Accuracy of the network on the 10000 rotated images: 91.75%
# Finished epoch, cumulative time: 559.0694029331207s
# [21, 500] loss: 0.0006, e-loss: 0.0004, Correct Rate: 99.94%
# Correctness on training epoch: 99.94%
# Accuracy of the network on the 10000 validation images: 98.79%
# Accuracy of the network on the 10000 translated images: 90.42%
# Accuracy of the network on the 10000 rotated images: 91.47%
# Finished epoch, cumulative time: 586.3713839054108s
# [22, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.91%
# Accuracy of the network on the 10000 translated images: 91.06%
# Accuracy of the network on the 10000 rotated images: 91.87%
# Finished epoch, cumulative time: 613.5786793231964s
# [23, 500] loss: 0.0003, e-loss: 0.0002, Correct Rate: 99.96%
# Correctness on training epoch: 99.96%
# Accuracy of the network on the 10000 validation images: 98.80%
# Accuracy of the network on the 10000 translated images: 90.58%
# Accuracy of the network on the 10000 rotated images: 91.48%
# Finished epoch, cumulative time: 641.1859488487244s
# [24, 500] loss: 0.0003, e-loss: 0.0002, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.85%
# Accuracy of the network on the 10000 translated images: 90.66%
# Accuracy of the network on the 10000 rotated images: 91.43%
# Finished epoch, cumulative time: 668.4899480342865s
# [25, 500] loss: 0.0003, e-loss: 0.0002, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.85%
# Accuracy of the network on the 10000 translated images: 90.61%
# Accuracy of the network on the 10000 rotated images: 91.49%
# Finished epoch, cumulative time: 695.7651081085205s
# Finished
# [1, 500] loss: 0.0203, e-loss: 0.0071, Correct Rate: 91.82%
# Correctness on training epoch: 91.82%
# Accuracy of the network on the 10000 validation images: 94.58%
# Accuracy of the network on the 10000 translated images: 70.51%
# Accuracy of the network on the 10000 rotated images: 76.34%
# Finished epoch, cumulative time: 25.92773413658142s
# [2, 500] loss: 0.0079, e-loss: 0.0036, Correct Rate: 97.43%
# Correctness on training epoch: 97.43%
# Accuracy of the network on the 10000 validation images: 96.92%
# Accuracy of the network on the 10000 translated images: 75.50%
# Accuracy of the network on the 10000 rotated images: 80.72%
# Finished epoch, cumulative time: 51.59621715545654s
# [3, 500] loss: 0.0062, e-loss: 0.0029, Correct Rate: 97.96%
# Correctness on training epoch: 97.96%
# Accuracy of the network on the 10000 validation images: 98.41%
# Accuracy of the network on the 10000 translated images: 79.64%
# Accuracy of the network on the 10000 rotated images: 84.02%
# Finished epoch, cumulative time: 77.44709873199463s
# [4, 500] loss: 0.0055, e-loss: 0.0027, Correct Rate: 98.23%
# Correctness on training epoch: 98.23%
# Accuracy of the network on the 10000 validation images: 97.74%
# Accuracy of the network on the 10000 translated images: 81.93%
# Accuracy of the network on the 10000 rotated images: 85.15%
# Finished epoch, cumulative time: 103.2571189403534s
# [5, 500] loss: 0.0046, e-loss: 0.0024, Correct Rate: 98.48%
# Correctness on training epoch: 98.48%
# Accuracy of the network on the 10000 validation images: 98.22%
# Accuracy of the network on the 10000 translated images: 81.83%
# Accuracy of the network on the 10000 rotated images: 85.79%
# Finished epoch, cumulative time: 128.8556833267212s
# [6, 500] loss: 0.0040, e-loss: 0.0021, Correct Rate: 98.78%
# Correctness on training epoch: 98.78%
# Accuracy of the network on the 10000 validation images: 98.31%
# Accuracy of the network on the 10000 translated images: 84.86%
# Accuracy of the network on the 10000 rotated images: 87.60%
# Finished epoch, cumulative time: 154.42058157920837s
# [7, 500] loss: 0.0033, e-loss: 0.0019, Correct Rate: 99.17%
# Correctness on training epoch: 99.17%
# Accuracy of the network on the 10000 validation images: 97.94%
# Accuracy of the network on the 10000 translated images: 84.18%
# Accuracy of the network on the 10000 rotated images: 86.63%
# Finished epoch, cumulative time: 180.6115972995758s
# [8, 500] loss: 0.0031, e-loss: 0.0017, Correct Rate: 99.10%
# Correctness on training epoch: 99.10%
# Accuracy of the network on the 10000 validation images: 98.48%
# Accuracy of the network on the 10000 translated images: 85.53%
# Accuracy of the network on the 10000 rotated images: 88.25%
# Finished epoch, cumulative time: 206.4465537071228s
# [9, 500] loss: 0.0027, e-loss: 0.0015, Correct Rate: 99.28%
# Correctness on training epoch: 99.28%
# Accuracy of the network on the 10000 validation images: 98.94%
# Accuracy of the network on the 10000 translated images: 86.95%
# Accuracy of the network on the 10000 rotated images: 89.25%
# Finished epoch, cumulative time: 232.17574763298035s
# [10, 500] loss: 0.0025, e-loss: 0.0014, Correct Rate: 99.19%
# Correctness on training epoch: 99.19%
# Accuracy of the network on the 10000 validation images: 98.57%
# Accuracy of the network on the 10000 translated images: 87.16%
# Accuracy of the network on the 10000 rotated images: 89.27%
# Finished epoch, cumulative time: 258.04966592788696s
# [11, 500] loss: 0.0021, e-loss: 0.0013, Correct Rate: 99.46%
# Correctness on training epoch: 99.46%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 87.92%
# Accuracy of the network on the 10000 rotated images: 89.57%
# Finished epoch, cumulative time: 283.697119474411s
# [12, 500] loss: 0.0018, e-loss: 0.0011, Correct Rate: 99.61%
# Correctness on training epoch: 99.61%
# Accuracy of the network on the 10000 validation images: 98.59%
# Accuracy of the network on the 10000 translated images: 87.89%
# Accuracy of the network on the 10000 rotated images: 89.50%
# Finished epoch, cumulative time: 309.29671692848206s
# [13, 500] loss: 0.0018, e-loss: 0.0011, Correct Rate: 99.52%
# Correctness on training epoch: 99.52%
# Accuracy of the network on the 10000 validation images: 97.77%
# Accuracy of the network on the 10000 translated images: 87.80%
# Accuracy of the network on the 10000 rotated images: 89.53%
# Finished epoch, cumulative time: 335.35516571998596s
# [14, 500] loss: 0.0015, e-loss: 0.0009, Correct Rate: 99.62%
# Correctness on training epoch: 99.62%
# Accuracy of the network on the 10000 validation images: 98.64%
# Accuracy of the network on the 10000 translated images: 89.55%
# Accuracy of the network on the 10000 rotated images: 90.96%
# Finished epoch, cumulative time: 361.1681339740753s
# [15, 500] loss: 0.0011, e-loss: 0.0008, Correct Rate: 99.82%
# Correctness on training epoch: 99.82%
# Accuracy of the network on the 10000 validation images: 98.87%
# Accuracy of the network on the 10000 translated images: 89.67%
# Accuracy of the network on the 10000 rotated images: 90.91%
# Finished epoch, cumulative time: 386.84166979789734s
# [16, 500] loss: 0.0009, e-loss: 0.0006, Correct Rate: 99.82%
# Correctness on training epoch: 99.82%
# Accuracy of the network on the 10000 validation images: 98.25%
# Accuracy of the network on the 10000 translated images: 88.33%
# Accuracy of the network on the 10000 rotated images: 89.89%
# Finished epoch, cumulative time: 412.89100408554077s
# [17, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.81%
# Correctness on training epoch: 99.81%
# Accuracy of the network on the 10000 validation images: 98.92%
# Accuracy of the network on the 10000 translated images: 89.97%
# Accuracy of the network on the 10000 rotated images: 91.07%
# Finished epoch, cumulative time: 438.6302263736725s
# [18, 500] loss: 0.0006, e-loss: 0.0005, Correct Rate: 99.95%
# Correctness on training epoch: 99.95%
# Accuracy of the network on the 10000 validation images: 98.78%
# Accuracy of the network on the 10000 translated images: 90.62%
# Accuracy of the network on the 10000 rotated images: 91.59%
# Finished epoch, cumulative time: 469.1973567008972s
# [19, 500] loss: 0.0010, e-loss: 0.0005, Correct Rate: 99.67%
# Correctness on training epoch: 99.67%
# Accuracy of the network on the 10000 validation images: 98.80%
# Accuracy of the network on the 10000 translated images: 90.00%
# Accuracy of the network on the 10000 rotated images: 91.38%
# Finished epoch, cumulative time: 498.8143446445465s
# [20, 500] loss: 0.0011, e-loss: 0.0006, Correct Rate: 99.74%
# Correctness on training epoch: 99.74%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 90.53%
# Accuracy of the network on the 10000 rotated images: 91.49%
# Finished epoch, cumulative time: 527.7547812461853s
# [21, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.87%
# Correctness on training epoch: 99.87%
# Accuracy of the network on the 10000 validation images: 98.94%
# Accuracy of the network on the 10000 translated images: 90.47%
# Accuracy of the network on the 10000 rotated images: 91.51%
# Finished epoch, cumulative time: 556.5732758045197s
# [22, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.94%
# Accuracy of the network on the 10000 translated images: 90.84%
# Accuracy of the network on the 10000 rotated images: 91.88%
# Finished epoch, cumulative time: 585.0343947410583s
# [23, 500] loss: 0.0003, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.95%
# Accuracy of the network on the 10000 translated images: 91.53%
# Accuracy of the network on the 10000 rotated images: 92.25%
# Finished epoch, cumulative time: 613.2550992965698s
# Finished
# [1, 500] loss: 0.0226, e-loss: 0.0071, Correct Rate: 90.62%
# Correctness on training epoch: 90.62%
# Accuracy of the network on the 10000 validation images: 97.28%
# Accuracy of the network on the 10000 translated images: 73.84%
# Accuracy of the network on the 10000 rotated images: 79.32%
# Finished epoch, cumulative time: 28.289346933364868s
# [2, 500] loss: 0.0085, e-loss: 0.0036, Correct Rate: 97.10%
# Correctness on training epoch: 97.10%
# Accuracy of the network on the 10000 validation images: 97.23%
# Accuracy of the network on the 10000 translated images: 76.12%
# Accuracy of the network on the 10000 rotated images: 81.13%
# Finished epoch, cumulative time: 56.5442795753479s
# [3, 500] loss: 0.0066, e-loss: 0.0030, Correct Rate: 97.73%
# Correctness on training epoch: 97.73%
# Accuracy of the network on the 10000 validation images: 97.02%
# Accuracy of the network on the 10000 translated images: 79.56%
# Accuracy of the network on the 10000 rotated images: 82.74%
# Finished epoch, cumulative time: 84.78490495681763s
# [4, 500] loss: 0.0054, e-loss: 0.0026, Correct Rate: 98.21%
# Correctness on training epoch: 98.21%
# Accuracy of the network on the 10000 validation images: 98.18%
# Accuracy of the network on the 10000 translated images: 81.59%
# Accuracy of the network on the 10000 rotated images: 85.14%
# Finished epoch, cumulative time: 113.13781023025513s
# [5, 500] loss: 0.0048, e-loss: 0.0024, Correct Rate: 98.53%
# Correctness on training epoch: 98.53%
# Accuracy of the network on the 10000 validation images: 98.02%
# Accuracy of the network on the 10000 translated images: 83.49%
# Accuracy of the network on the 10000 rotated images: 86.63%
# Finished epoch, cumulative time: 141.28708386421204s
# [6, 500] loss: 0.0042, e-loss: 0.0021, Correct Rate: 98.62%
# Correctness on training epoch: 98.62%
# Accuracy of the network on the 10000 validation images: 98.53%
# Accuracy of the network on the 10000 translated images: 84.14%
# Accuracy of the network on the 10000 rotated images: 87.44%
# Finished epoch, cumulative time: 169.54179286956787s
# [7, 500] loss: 0.0038, e-loss: 0.0019, Correct Rate: 98.87%
# Correctness on training epoch: 98.87%
# Accuracy of the network on the 10000 validation images: 98.40%
# Accuracy of the network on the 10000 translated images: 84.99%
# Accuracy of the network on the 10000 rotated images: 87.99%
# Finished epoch, cumulative time: 197.86236333847046s
# [8, 500] loss: 0.0031, e-loss: 0.0017, Correct Rate: 99.14%
# Correctness on training epoch: 99.14%
# Accuracy of the network on the 10000 validation images: 98.40%
# Accuracy of the network on the 10000 translated images: 86.31%
# Accuracy of the network on the 10000 rotated images: 88.46%
# Finished epoch, cumulative time: 226.79168939590454s
# [9, 500] loss: 0.0029, e-loss: 0.0016, Correct Rate: 99.14%
# Correctness on training epoch: 99.14%
# Accuracy of the network on the 10000 validation images: 98.35%
# Accuracy of the network on the 10000 translated images: 87.36%
# Accuracy of the network on the 10000 rotated images: 89.24%
# Finished epoch, cumulative time: 257.7745666503906s
# [10, 500] loss: 0.0024, e-loss: 0.0014, Correct Rate: 99.42%
# Correctness on training epoch: 99.42%
# Accuracy of the network on the 10000 validation images: 97.83%
# Accuracy of the network on the 10000 translated images: 84.58%
# Accuracy of the network on the 10000 rotated images: 86.53%
# Finished epoch, cumulative time: 287.08633399009705s
# [11, 500] loss: 0.0025, e-loss: 0.0013, Correct Rate: 99.33%
# Correctness on training epoch: 99.33%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 88.80%
# Accuracy of the network on the 10000 rotated images: 90.42%
# Finished epoch, cumulative time: 318.3113842010498s
# [12, 500] loss: 0.0022, e-loss: 0.0013, Correct Rate: 99.39%
# Correctness on training epoch: 99.39%
# Accuracy of the network on the 10000 validation images: 97.84%
# Accuracy of the network on the 10000 translated images: 86.38%
# Accuracy of the network on the 10000 rotated images: 87.95%
# Finished epoch, cumulative time: 349.1758143901825s
# [13, 500] loss: 0.0021, e-loss: 0.0012, Correct Rate: 99.33%
# Correctness on training epoch: 99.33%
# Accuracy of the network on the 10000 validation images: 98.53%
# Accuracy of the network on the 10000 translated images: 87.91%
# Accuracy of the network on the 10000 rotated images: 89.51%
# Finished epoch, cumulative time: 379.0139720439911s
# [14, 500] loss: 0.0017, e-loss: 0.0011, Correct Rate: 99.58%
# Correctness on training epoch: 99.58%
# Accuracy of the network on the 10000 validation images: 98.69%
# Accuracy of the network on the 10000 translated images: 88.92%
# Accuracy of the network on the 10000 rotated images: 90.26%
# Finished epoch, cumulative time: 410.2739815711975s
# [15, 500] loss: 0.0016, e-loss: 0.0009, Correct Rate: 99.60%
# Correctness on training epoch: 99.60%
# Accuracy of the network on the 10000 validation images: 98.12%
# Accuracy of the network on the 10000 translated images: 87.36%
# Accuracy of the network on the 10000 rotated images: 89.03%
# Finished epoch, cumulative time: 440.1593916416168s
# [16, 500] loss: 0.0012, e-loss: 0.0008, Correct Rate: 99.78%
# Correctness on training epoch: 99.78%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 90.16%
# Accuracy of the network on the 10000 rotated images: 91.14%
# Finished epoch, cumulative time: 469.8148846626282s
# [17, 500] loss: 0.0010, e-loss: 0.0007, Correct Rate: 99.81%
# Correctness on training epoch: 99.81%
# Accuracy of the network on the 10000 validation images: 98.85%
# Accuracy of the network on the 10000 translated images: 90.31%
# Accuracy of the network on the 10000 rotated images: 91.23%
# Finished epoch, cumulative time: 499.994580745697s
# [18, 500] loss: 0.0009, e-loss: 0.0006, Correct Rate: 99.86%
# Correctness on training epoch: 99.86%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 90.05%
# Accuracy of the network on the 10000 rotated images: 91.23%
# Finished epoch, cumulative time: 528.8595185279846s
# [19, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.89%
# Correctness on training epoch: 99.89%
# Accuracy of the network on the 10000 validation images: 98.83%
# Accuracy of the network on the 10000 translated images: 90.64%
# Accuracy of the network on the 10000 rotated images: 91.64%
# Finished epoch, cumulative time: 557.5238945484161s
# [20, 500] loss: 0.0008, e-loss: 0.0004, Correct Rate: 99.76%
# Correctness on training epoch: 99.76%
# Accuracy of the network on the 10000 validation images: 98.29%
# Accuracy of the network on the 10000 translated images: 88.58%
# Accuracy of the network on the 10000 rotated images: 89.98%
# Finished epoch, cumulative time: 587.1617200374603s
# [21, 500] loss: 0.0011, e-loss: 0.0007, Correct Rate: 99.75%
# Correctness on training epoch: 99.75%
# Accuracy of the network on the 10000 validation images: 98.63%
# Accuracy of the network on the 10000 translated images: 90.22%
# Accuracy of the network on the 10000 rotated images: 91.18%
# Finished epoch, cumulative time: 616.7179172039032s
# [22, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.75%
# Accuracy of the network on the 10000 translated images: 90.75%
# Accuracy of the network on the 10000 rotated images: 91.47%
# Finished epoch, cumulative time: 645.3424165248871s
# [23, 500] loss: 0.0004, e-loss: 0.0004, Correct Rate: 99.98%
# Correctness on training epoch: 99.98%
# Accuracy of the network on the 10000 validation images: 98.89%
# Accuracy of the network on the 10000 translated images: 91.12%
# Accuracy of the network on the 10000 rotated images: 91.93%
# Finished epoch, cumulative time: 673.9638738632202s
# [24, 500] loss: 0.0003, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 91.63%
# Accuracy of the network on the 10000 rotated images: 92.04%
# Finished epoch, cumulative time: 702.9972960948944s
# [25, 500] loss: 0.0003, e-loss: 0.0002, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.86%
# Accuracy of the network on the 10000 translated images: 91.17%
# Accuracy of the network on the 10000 rotated images: 91.63%
# Finished epoch, cumulative time: 731.6687526702881s
# Finished
# Allowing Windows to go to sleep
