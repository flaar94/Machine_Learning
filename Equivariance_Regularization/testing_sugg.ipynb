# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split
from torch.utils.data.sampler import SubsetRandomSampler
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time
from windows_inhibitor import WindowsInhibitor
from groupy.gconv.pytorch_gconv.splitgconv2d import P4MConvZ2, P4MConvP4M, P4ConvZ2, P4ConvP4
from groupy.gconv.pytorch_gconv.pooling import plane_group_spatial_max_pooling
import logging
logging.basicConfig(level=logging.INFO, filename='testing_sugg.log', 
                    format='%(asctime)s:%(name)s:%(levelname)s:%(message)s')
logging.info('Starting New Test')

# %%
indices = list(range(60_000))
train_indices = indices[:10_000]
valid_indices = indices[50_000:]
logging.info(f'Train length: {len(train_indices)}')
logging.info(f'Valid length: {len(valid_indices)}')

# %%
AUGMENT = False
if AUGMENT:
    train_transform = transforms.Compose([
    transforms.RandomAffine(15, translate=(0.1, 0.1), scale=(0.95, 1.05)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])
    
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
else:
    train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
    
logging.info(f'train_transform: {repr(train_transform)}')
logging.info(f'valid_transform: {repr(valid_transform)}')
    
translate_transform = transforms.Compose([
    transforms.RandomAffine(0, translate=(0.2, 0.2), scale=(1, 1)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])

rotate_transform = transforms.Compose([
    transforms.RandomAffine(30),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))])

train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

train_set = torchvision.datasets.MNIST(root='./data', train=True,
                                      download=True, transform=train_transform)
valid_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=valid_transform)
translate_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=translate_transform)
rotation_set = torchvision.datasets.MNIST(root='./data', train=False,
                                      download=True, transform=rotate_transform)

classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal',
               'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
USE_CUDA = True
BASE = 1
LAMBDA = 3_000_000
DECAY = 0.1**6
logging.info(f'BASE = {BASE}, LAMBDA = {LAMBDA}, DECAY = {DECAY}')
LR = 0.01
LR_BASE = 0.95
MOMENTUM = 0.5
logging.info(f'LR = {LR}, LR_BASE = {LR_BASE}, MOMENTUM = {MOMENTUM}')

trainloader = torch.utils.data.DataLoader(train_set, batch_size=20, sampler=train_sampler,
                                          shuffle=False, num_workers=2, pin_memory=USE_CUDA)
validation_loader = torch.utils.data.DataLoader(valid_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)
translate_loader = torch.utils.data.DataLoader(translate_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)
rotation_loader = torch.utils.data.DataLoader(rotation_set, batch_size=256,
                                         shuffle=False, num_workers=2, pin_memory=False)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = P4ConvZ2(1, 16, kernel_size=3)
        self.conv2 = P4ConvP4(16, 32, kernel_size=3)
        self.conv4 = P4ConvP4(32, 64, kernel_size=3)
        self.conv5 = P4ConvP4(64, 128, kernel_size=3)
        self.fc1 = nn.Linear(4 * 4 * 128 * 4, 10)
        self.prior_mean = nn.Parameter(torch.zeros([128, 10, 1, 1, 1], requires_grad=True))

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = plane_group_spatial_max_pooling(x, 2, 2)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = plane_group_spatial_max_pooling(x, 2, 2)
        x = x.view(x.size()[0], -1)
        x = self.fc1(x)
        return x

# %%
def run():
    net = Net()
    train_error_list = []
    test_error_list = []
    true_epoch = 0
    total_time = 0
    torch.cuda.empty_cache()
    logging.info(repr(net))
    
    criterion = nn.CrossEntropyLoss()
    equivariant_loss = nn.MSELoss()
    logging.info(f'equivariant loss function: {repr(equivariant_loss)}')

    device = torch.device("cuda:0" if USE_CUDA else "cpu")
    net.to(device)
    learned_train_set = False
    for epoch in range(80):  
        # loop over the dataset multiple times
        start_time = time.time()
        optimizer = optim.SGD(net.parameters(), lr=LR * LR_BASE ** true_epoch, momentum=MOMENTUM, weight_decay=DECAY)
        little_lambda = (1/len(trainloader)) * LAMBDA * BASE ** true_epoch
        true_epoch += 1
        logging.info(f'Starting epoch {true_epoch}')
        running_loss = 0.0
        true_train_total = 0.0
        correct_train_total = 0.0
        correct_train = 0.0
        total_train = 0.0
        total_equi_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # zero the parameter gradients
            optimizer.zero_grad()
    
            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            
            nonequiv_weights1 = net.fc1.weight
            nonequiv_weights1 = nonequiv_weights1.view(128, 10, 4, 4, 4)
            prime_weights = net.prior_mean.expand(128, 10, 4, 4, 4)
            if little_lambda:
                total_equi_loss += equivariant_loss(nonequiv_weights1, prime_weights).detach()*little_lambda
                loss += little_lambda * equivariant_loss(nonequiv_weights1, prime_weights)

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            true_train_total += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            correct_train_total += (predicted == labels).sum().item()

            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 500 == 499:  
                # print every 500 mini-batches
                msg = f'[{true_epoch}, {i + 1}] loss: {running_loss / total_train:.4f}, ' \
                      f'e-loss: {total_equi_loss / total_train:.4f}, ' \
                      f'Correct Rate: {100 * correct_train / total_train:.2f}%'
                print(msg)
                
                running_loss = 0.0
                correct_train = 0.0
                total_train = 0.0
                total_equi_loss = 0.0
        train_error_list.append(100*correct_train_total / true_train_total)
        print(f"Correctness on training epoch: {100*correct_train_total / true_train_total:.2f}%")
        logging.info(f"Correctness on training epoch: {100*correct_train_total / true_train_total:.2f}%")
        correct = 0
        total = 0
        with torch.no_grad():
            for val_data in validation_loader:
                images, labels = val_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 validation images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 validation images: {100 * correct / total:.2f}%')
            for trans_data in translate_loader:
                images, labels = trans_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 translated images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 translated images: {100 * correct / total:.2f}%')
            for rotate_data in rotation_loader:
                images, labels = rotate_data
                images, labels = images.to(device), labels.to(device)
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            test_error_list.append(100 * correct / total)
            print(f'Accuracy of the network on the 10000 rotated images: {100 * correct / total:.2f}%')
            logging.info(f'Accuracy of the network on the 10000 rotated images: {100 * correct / total:.2f}%')
        total_time += time.time() - start_time
        print(f'Finished epoch, cumulative time: {total_time}s')
        if correct_train_total == true_train_total:
            if not learned_train_set:
                learned_train_set = True
            else:
                break
    print("Finished")
    logging.info("Finished")

# %%
with WindowsInhibitor():
    logging.info("-----------------------Starting Testing--------------------------------")
    for i in range(3,6):
        logging.info(f'-------------------------Starting test {i}----------------------------')
        run()
    logging.info(f'-------------------------Testing Finished----------------------------')
# Out:
# Preventing Windows from going to sleep
# [1, 500] loss: 0.0235, e-loss: 0.0086, Correct Rate: 90.75%
# Correctness on training epoch: 90.75%
# Accuracy of the network on the 10000 validation images: 96.84%
# Accuracy of the network on the 10000 translated images: 70.61%
# Accuracy of the network on the 10000 rotated images: 76.98%
# Finished epoch, cumulative time: 28.89766788482666s
# [2, 500] loss: 0.0104, e-loss: 0.0050, Correct Rate: 96.74%
# Correctness on training epoch: 96.74%
# Accuracy of the network on the 10000 validation images: 96.57%
# Accuracy of the network on the 10000 translated images: 71.61%
# Accuracy of the network on the 10000 rotated images: 78.03%
# Finished epoch, cumulative time: 56.465943574905396s
# [3, 500] loss: 0.0090, e-loss: 0.0045, Correct Rate: 97.19%
# Correctness on training epoch: 97.19%
# Accuracy of the network on the 10000 validation images: 97.66%
# Accuracy of the network on the 10000 translated images: 74.22%
# Accuracy of the network on the 10000 rotated images: 79.78%
# Finished epoch, cumulative time: 83.6742160320282s
# [4, 500] loss: 0.0078, e-loss: 0.0041, Correct Rate: 97.82%
# Correctness on training epoch: 97.82%
# Accuracy of the network on the 10000 validation images: 96.25%
# Accuracy of the network on the 10000 translated images: 73.74%
# Accuracy of the network on the 10000 rotated images: 78.95%
# Finished epoch, cumulative time: 110.62414479255676s
# [5, 500] loss: 0.0073, e-loss: 0.0038, Correct Rate: 97.98%
# Correctness on training epoch: 97.98%
# Accuracy of the network on the 10000 validation images: 97.42%
# Accuracy of the network on the 10000 translated images: 76.50%
# Accuracy of the network on the 10000 rotated images: 81.28%
# Finished epoch, cumulative time: 137.57643795013428s
# [6, 500] loss: 0.0065, e-loss: 0.0037, Correct Rate: 98.29%
# Correctness on training epoch: 98.29%
# Accuracy of the network on the 10000 validation images: 97.75%
# Accuracy of the network on the 10000 translated images: 76.30%
# Accuracy of the network on the 10000 rotated images: 81.28%
# Finished epoch, cumulative time: 164.6251130104065s
# [7, 500] loss: 0.0063, e-loss: 0.0034, Correct Rate: 98.24%
# Correctness on training epoch: 98.24%
# Accuracy of the network on the 10000 validation images: 97.26%
# Accuracy of the network on the 10000 translated images: 77.04%
# Accuracy of the network on the 10000 rotated images: 81.82%
# Finished epoch, cumulative time: 191.76150941848755s
# [8, 500] loss: 0.0059, e-loss: 0.0034, Correct Rate: 98.31%
# Correctness on training epoch: 98.31%
# Accuracy of the network on the 10000 validation images: 96.66%
# Accuracy of the network on the 10000 translated images: 76.53%
# Accuracy of the network on the 10000 rotated images: 81.09%
# Finished epoch, cumulative time: 218.77430748939514s
# [9, 500] loss: 0.0051, e-loss: 0.0031, Correct Rate: 98.71%
# Correctness on training epoch: 98.71%
# Accuracy of the network on the 10000 validation images: 98.29%
# Accuracy of the network on the 10000 translated images: 79.18%
# Accuracy of the network on the 10000 rotated images: 83.65%
# Finished epoch, cumulative time: 245.7431824207306s
# [10, 500] loss: 0.0051, e-loss: 0.0030, Correct Rate: 98.69%
# Correctness on training epoch: 98.69%
# Accuracy of the network on the 10000 validation images: 92.28%
# Accuracy of the network on the 10000 translated images: 72.48%
# Accuracy of the network on the 10000 rotated images: 76.32%
# Finished epoch, cumulative time: 273.12794852256775s
# [11, 500] loss: 0.0046, e-loss: 0.0028, Correct Rate: 98.95%
# Correctness on training epoch: 98.95%
# Accuracy of the network on the 10000 validation images: 98.54%
# Accuracy of the network on the 10000 translated images: 79.48%
# Accuracy of the network on the 10000 rotated images: 84.09%
# Finished epoch, cumulative time: 300.33415699005127s
# [12, 500] loss: 0.0042, e-loss: 0.0025, Correct Rate: 99.05%
# Correctness on training epoch: 99.05%
# Accuracy of the network on the 10000 validation images: 97.06%
# Accuracy of the network on the 10000 translated images: 78.07%
# Accuracy of the network on the 10000 rotated images: 82.07%
# Finished epoch, cumulative time: 327.41277623176575s
# [13, 500] loss: 0.0042, e-loss: 0.0025, Correct Rate: 98.98%
# Correctness on training epoch: 98.98%
# Accuracy of the network on the 10000 validation images: 98.03%
# Accuracy of the network on the 10000 translated images: 80.37%
# Accuracy of the network on the 10000 rotated images: 84.61%
# Finished epoch, cumulative time: 354.3439202308655s
# [14, 500] loss: 0.0036, e-loss: 0.0023, Correct Rate: 99.19%
# Correctness on training epoch: 99.19%
# Accuracy of the network on the 10000 validation images: 98.54%
# Accuracy of the network on the 10000 translated images: 80.33%
# Accuracy of the network on the 10000 rotated images: 84.89%
# Finished epoch, cumulative time: 381.5265896320343s
# [15, 500] loss: 0.0033, e-loss: 0.0022, Correct Rate: 99.34%
# Correctness on training epoch: 99.34%
# Accuracy of the network on the 10000 validation images: 98.45%
# Accuracy of the network on the 10000 translated images: 82.17%
# Accuracy of the network on the 10000 rotated images: 86.03%
# Finished epoch, cumulative time: 408.5792906284332s
# [16, 500] loss: 0.0035, e-loss: 0.0020, Correct Rate: 99.09%
# Correctness on training epoch: 99.09%
# Accuracy of the network on the 10000 validation images: 98.25%
# Accuracy of the network on the 10000 translated images: 81.67%
# Accuracy of the network on the 10000 rotated images: 85.11%
# Finished epoch, cumulative time: 435.87335324287415s
# [17, 500] loss: 0.0030, e-loss: 0.0020, Correct Rate: 99.34%
# Correctness on training epoch: 99.34%
# Accuracy of the network on the 10000 validation images: 98.20%
# Accuracy of the network on the 10000 translated images: 81.94%
# Accuracy of the network on the 10000 rotated images: 85.49%
# Finished epoch, cumulative time: 465.4821364879608s
# [18, 500] loss: 0.0030, e-loss: 0.0019, Correct Rate: 99.29%
# Correctness on training epoch: 99.29%
# Accuracy of the network on the 10000 validation images: 98.27%
# Accuracy of the network on the 10000 translated images: 82.27%
# Accuracy of the network on the 10000 rotated images: 86.03%
# Finished epoch, cumulative time: 495.59061789512634s
# [19, 500] loss: 0.0028, e-loss: 0.0018, Correct Rate: 99.37%
# Correctness on training epoch: 99.37%
# Accuracy of the network on the 10000 validation images: 98.55%
# Accuracy of the network on the 10000 translated images: 83.03%
# Accuracy of the network on the 10000 rotated images: 86.48%
# Finished epoch, cumulative time: 525.9982991218567s
# [20, 500] loss: 0.0027, e-loss: 0.0017, Correct Rate: 99.38%
# Correctness on training epoch: 99.38%
# Accuracy of the network on the 10000 validation images: 97.79%
# Accuracy of the network on the 10000 translated images: 81.95%
# Accuracy of the network on the 10000 rotated images: 85.21%
# Finished epoch, cumulative time: 557.0502569675446s
# [21, 500] loss: 0.0021, e-loss: 0.0015, Correct Rate: 99.68%
# Correctness on training epoch: 99.68%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 83.42%
# Accuracy of the network on the 10000 rotated images: 86.76%
# Finished epoch, cumulative time: 588.0284471511841s
# [22, 500] loss: 0.0025, e-loss: 0.0015, Correct Rate: 99.41%
# Correctness on training epoch: 99.41%
# Accuracy of the network on the 10000 validation images: 98.15%
# Accuracy of the network on the 10000 translated images: 83.24%
# Accuracy of the network on the 10000 rotated images: 85.71%
# Finished epoch, cumulative time: 619.1222598552704s
# [23, 500] loss: 0.0020, e-loss: 0.0014, Correct Rate: 99.65%
# Correctness on training epoch: 99.65%
# Accuracy of the network on the 10000 validation images: 98.23%
# Accuracy of the network on the 10000 translated images: 83.28%
# Accuracy of the network on the 10000 rotated images: 86.45%
# Finished epoch, cumulative time: 649.7094631195068s
# [24, 500] loss: 0.0017, e-loss: 0.0012, Correct Rate: 99.72%
# Correctness on training epoch: 99.72%
# Accuracy of the network on the 10000 validation images: 98.63%
# Accuracy of the network on the 10000 translated images: 84.44%
# Accuracy of the network on the 10000 rotated images: 87.39%
# Finished epoch, cumulative time: 679.017086982727s
# [25, 500] loss: 0.0020, e-loss: 0.0012, Correct Rate: 99.53%
# Correctness on training epoch: 99.53%
# Accuracy of the network on the 10000 validation images: 98.01%
# Accuracy of the network on the 10000 translated images: 82.36%
# Accuracy of the network on the 10000 rotated images: 85.78%
# Finished epoch, cumulative time: 709.2464733123779s
# [26, 500] loss: 0.0015, e-loss: 0.0011, Correct Rate: 99.84%
# Correctness on training epoch: 99.84%
# Accuracy of the network on the 10000 validation images: 98.79%
# Accuracy of the network on the 10000 translated images: 84.36%
# Accuracy of the network on the 10000 rotated images: 87.63%
# Finished epoch, cumulative time: 739.3800482749939s
# [27, 500] loss: 0.0016, e-loss: 0.0011, Correct Rate: 99.73%
# Correctness on training epoch: 99.73%
# Accuracy of the network on the 10000 validation images: 98.62%
# Accuracy of the network on the 10000 translated images: 84.50%
# Accuracy of the network on the 10000 rotated images: 87.37%
# Finished epoch, cumulative time: 769.5904641151428s
# [28, 500] loss: 0.0011, e-loss: 0.0009, Correct Rate: 99.90%
# Correctness on training epoch: 99.90%
# Accuracy of the network on the 10000 validation images: 98.78%
# Accuracy of the network on the 10000 translated images: 84.39%
# Accuracy of the network on the 10000 rotated images: 87.38%
# Finished epoch, cumulative time: 799.0899119377136s
# [29, 500] loss: 0.0012, e-loss: 0.0008, Correct Rate: 99.76%
# Correctness on training epoch: 99.76%
# Accuracy of the network on the 10000 validation images: 98.25%
# Accuracy of the network on the 10000 translated images: 83.69%
# Accuracy of the network on the 10000 rotated images: 86.81%
# Finished epoch, cumulative time: 828.6409180164337s
# [30, 500] loss: 0.0012, e-loss: 0.0008, Correct Rate: 99.83%
# Correctness on training epoch: 99.83%
# Accuracy of the network on the 10000 validation images: 98.79%
# Accuracy of the network on the 10000 translated images: 84.88%
# Accuracy of the network on the 10000 rotated images: 87.78%
# Finished epoch, cumulative time: 858.5518958568573s
# [31, 500] loss: 0.0009, e-loss: 0.0007, Correct Rate: 99.95%
# Correctness on training epoch: 99.95%
# Accuracy of the network on the 10000 validation images: 98.83%
# Accuracy of the network on the 10000 translated images: 85.64%
# Accuracy of the network on the 10000 rotated images: 88.33%
# Finished epoch, cumulative time: 889.5042290687561s
# [32, 500] loss: 0.0014, e-loss: 0.0007, Correct Rate: 99.68%
# Correctness on training epoch: 99.68%
# Accuracy of the network on the 10000 validation images: 98.73%
# Accuracy of the network on the 10000 translated images: 83.93%
# Accuracy of the network on the 10000 rotated images: 87.33%
# Finished epoch, cumulative time: 918.8008823394775s
# [33, 500] loss: 0.0013, e-loss: 0.0009, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.69%
# Accuracy of the network on the 10000 translated images: 84.86%
# Accuracy of the network on the 10000 rotated images: 87.61%
# Finished epoch, cumulative time: 948.0271253585815s
# [34, 500] loss: 0.0009, e-loss: 0.0007, Correct Rate: 99.98%
# Correctness on training epoch: 99.98%
# Accuracy of the network on the 10000 validation images: 98.83%
# Accuracy of the network on the 10000 translated images: 85.90%
# Accuracy of the network on the 10000 rotated images: 88.53%
# Finished epoch, cumulative time: 977.4883804321289s
# [35, 500] loss: 0.0009, e-loss: 0.0006, Correct Rate: 99.84%
# Correctness on training epoch: 99.84%
# Accuracy of the network on the 10000 validation images: 98.77%
# Accuracy of the network on the 10000 translated images: 84.25%
# Accuracy of the network on the 10000 rotated images: 87.43%
# Finished epoch, cumulative time: 1006.8688242435455s
# [36, 500] loss: 0.0007, e-loss: 0.0006, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.91%
# Accuracy of the network on the 10000 translated images: 86.25%
# Accuracy of the network on the 10000 rotated images: 88.80%
# Finished epoch, cumulative time: 1034.7653279304504s
# [37, 500] loss: 0.0006, e-loss: 0.0005, Correct Rate: 99.95%
# Correctness on training epoch: 99.95%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 85.34%
# Accuracy of the network on the 10000 rotated images: 88.24%
# Finished epoch, cumulative time: 1062.810467004776s
# [38, 500] loss: 0.0006, e-loss: 0.0004, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.73%
# Accuracy of the network on the 10000 translated images: 86.07%
# Accuracy of the network on the 10000 rotated images: 88.52%
# Finished epoch, cumulative time: 1091.897225856781s
# [39, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 99.97%
# Correctness on training epoch: 99.97%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 86.18%
# Accuracy of the network on the 10000 rotated images: 88.60%
# Finished epoch, cumulative time: 1119.6490120887756s
# [40, 500] loss: 0.0006, e-loss: 0.0004, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.76%
# Accuracy of the network on the 10000 translated images: 85.30%
# Accuracy of the network on the 10000 rotated images: 87.88%
# Finished epoch, cumulative time: 1147.0797510147095s
# [41, 500] loss: 0.0007, e-loss: 0.0004, Correct Rate: 99.89%
# Correctness on training epoch: 99.89%
# Accuracy of the network on the 10000 validation images: 98.85%
# Accuracy of the network on the 10000 translated images: 85.72%
# Accuracy of the network on the 10000 rotated images: 88.62%
# Finished epoch, cumulative time: 1174.4561681747437s
# [42, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 85.79%
# Accuracy of the network on the 10000 rotated images: 88.41%
# Finished epoch, cumulative time: 1201.754235982895s
# [43, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.71%
# Accuracy of the network on the 10000 translated images: 85.75%
# Accuracy of the network on the 10000 rotated images: 88.27%
# Finished epoch, cumulative time: 1228.9025838375092s
# Finished
# [1, 500] loss: 0.0246, e-loss: 0.0086, Correct Rate: 90.14%
# Correctness on training epoch: 90.14%
# Accuracy of the network on the 10000 validation images: 95.93%
# Accuracy of the network on the 10000 translated images: 68.89%
# Accuracy of the network on the 10000 rotated images: 75.37%
# Finished epoch, cumulative time: 27.22028636932373s
# [2, 500] loss: 0.0106, e-loss: 0.0051, Correct Rate: 96.71%
# Correctness on training epoch: 96.71%
# Accuracy of the network on the 10000 validation images: 97.79%
# Accuracy of the network on the 10000 translated images: 72.08%
# Accuracy of the network on the 10000 rotated images: 79.00%
# Finished epoch, cumulative time: 54.50727987289429s
# [3, 500] loss: 0.0089, e-loss: 0.0045, Correct Rate: 97.26%
# Correctness on training epoch: 97.26%
# Accuracy of the network on the 10000 validation images: 96.50%
# Accuracy of the network on the 10000 translated images: 73.62%
# Accuracy of the network on the 10000 rotated images: 79.01%
# Finished epoch, cumulative time: 82.25644636154175s
# [4, 500] loss: 0.0077, e-loss: 0.0041, Correct Rate: 97.78%
# Correctness on training epoch: 97.78%
# Accuracy of the network on the 10000 validation images: 97.38%
# Accuracy of the network on the 10000 translated images: 76.05%
# Accuracy of the network on the 10000 rotated images: 81.37%
# Finished epoch, cumulative time: 109.60231590270996s
# [5, 500] loss: 0.0069, e-loss: 0.0037, Correct Rate: 97.87%
# Correctness on training epoch: 97.87%
# Accuracy of the network on the 10000 validation images: 97.20%
# Accuracy of the network on the 10000 translated images: 73.49%
# Accuracy of the network on the 10000 rotated images: 79.73%
# Finished epoch, cumulative time: 137.3447585105896s
# [6, 500] loss: 0.0068, e-loss: 0.0036, Correct Rate: 98.28%
# Correctness on training epoch: 98.28%
# Accuracy of the network on the 10000 validation images: 97.62%
# Accuracy of the network on the 10000 translated images: 76.19%
# Accuracy of the network on the 10000 rotated images: 81.58%
# Finished epoch, cumulative time: 167.12840294837952s
# [7, 500] loss: 0.0058, e-loss: 0.0033, Correct Rate: 98.32%
# Correctness on training epoch: 98.32%
# Accuracy of the network on the 10000 validation images: 98.06%
# Accuracy of the network on the 10000 translated images: 77.89%
# Accuracy of the network on the 10000 rotated images: 82.58%
# Finished epoch, cumulative time: 197.92205166816711s
# [8, 500] loss: 0.0056, e-loss: 0.0032, Correct Rate: 98.58%
# Correctness on training epoch: 98.58%
# Accuracy of the network on the 10000 validation images: 98.48%
# Accuracy of the network on the 10000 translated images: 78.64%
# Accuracy of the network on the 10000 rotated images: 83.99%
# Finished epoch, cumulative time: 228.97158980369568s
# [9, 500] loss: 0.0050, e-loss: 0.0029, Correct Rate: 98.77%
# Correctness on training epoch: 98.77%
# Accuracy of the network on the 10000 validation images: 97.79%
# Accuracy of the network on the 10000 translated images: 78.39%
# Accuracy of the network on the 10000 rotated images: 83.09%
# Finished epoch, cumulative time: 260.5079700946808s
# [10, 500] loss: 0.0050, e-loss: 0.0029, Correct Rate: 98.56%
# Correctness on training epoch: 98.56%
# Accuracy of the network on the 10000 validation images: 98.33%
# Accuracy of the network on the 10000 translated images: 78.12%
# Accuracy of the network on the 10000 rotated images: 83.36%
# Finished epoch, cumulative time: 292.0717759132385s
# [11, 500] loss: 0.0045, e-loss: 0.0028, Correct Rate: 98.86%
# Correctness on training epoch: 98.86%
# Accuracy of the network on the 10000 validation images: 97.22%
# Accuracy of the network on the 10000 translated images: 77.43%
# Accuracy of the network on the 10000 rotated images: 82.20%
# Finished epoch, cumulative time: 324.7934374809265s
# [12, 500] loss: 0.0045, e-loss: 0.0026, Correct Rate: 98.97%
# Correctness on training epoch: 98.97%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 81.89%
# Accuracy of the network on the 10000 rotated images: 85.92%
# Finished epoch, cumulative time: 357.81831669807434s
# [13, 500] loss: 0.0038, e-loss: 0.0023, Correct Rate: 99.01%
# Correctness on training epoch: 99.01%
# Accuracy of the network on the 10000 validation images: 98.16%
# Accuracy of the network on the 10000 translated images: 81.01%
# Accuracy of the network on the 10000 rotated images: 85.24%
# Finished epoch, cumulative time: 389.28823947906494s
# [14, 500] loss: 0.0036, e-loss: 0.0022, Correct Rate: 99.15%
# Correctness on training epoch: 99.15%
# Accuracy of the network on the 10000 validation images: 98.36%
# Accuracy of the network on the 10000 translated images: 82.06%
# Accuracy of the network on the 10000 rotated images: 85.75%
# Finished epoch, cumulative time: 418.7502498626709s
# [15, 500] loss: 0.0037, e-loss: 0.0023, Correct Rate: 99.15%
# Correctness on training epoch: 99.15%
# Accuracy of the network on the 10000 validation images: 98.16%
# Accuracy of the network on the 10000 translated images: 80.94%
# Accuracy of the network on the 10000 rotated images: 84.40%
# Finished epoch, cumulative time: 447.0720627307892s
# [16, 500] loss: 0.0035, e-loss: 0.0021, Correct Rate: 99.13%
# Correctness on training epoch: 99.13%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 81.96%
# Accuracy of the network on the 10000 rotated images: 86.02%
# Finished epoch, cumulative time: 474.4330732822418s
# [17, 500] loss: 0.0032, e-loss: 0.0020, Correct Rate: 99.31%
# Correctness on training epoch: 99.31%
# Accuracy of the network on the 10000 validation images: 98.73%
# Accuracy of the network on the 10000 translated images: 84.12%
# Accuracy of the network on the 10000 rotated images: 87.45%
# Finished epoch, cumulative time: 501.98086881637573s
# [18, 500] loss: 0.0030, e-loss: 0.0019, Correct Rate: 99.24%
# Correctness on training epoch: 99.24%
# Accuracy of the network on the 10000 validation images: 98.81%
# Accuracy of the network on the 10000 translated images: 84.17%
# Accuracy of the network on the 10000 rotated images: 87.40%
# Finished epoch, cumulative time: 529.2093453407288s
# [19, 500] loss: 0.0024, e-loss: 0.0017, Correct Rate: 99.61%
# Correctness on training epoch: 99.61%
# Accuracy of the network on the 10000 validation images: 98.26%
# Accuracy of the network on the 10000 translated images: 83.67%
# Accuracy of the network on the 10000 rotated images: 86.56%
# Finished epoch, cumulative time: 556.5611290931702s
# [20, 500] loss: 0.0024, e-loss: 0.0015, Correct Rate: 99.46%
# Correctness on training epoch: 99.46%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 82.77%
# Accuracy of the network on the 10000 rotated images: 86.42%
# Finished epoch, cumulative time: 584.1105835437775s
# [21, 500] loss: 0.0022, e-loss: 0.0015, Correct Rate: 99.60%
# Correctness on training epoch: 99.60%
# Accuracy of the network on the 10000 validation images: 98.80%
# Accuracy of the network on the 10000 translated images: 82.44%
# Accuracy of the network on the 10000 rotated images: 86.47%
# Finished epoch, cumulative time: 611.5234715938568s
# [22, 500] loss: 0.0022, e-loss: 0.0015, Correct Rate: 99.51%
# Correctness on training epoch: 99.51%
# Accuracy of the network on the 10000 validation images: 98.24%
# Accuracy of the network on the 10000 translated images: 82.54%
# Accuracy of the network on the 10000 rotated images: 85.91%
# Finished epoch, cumulative time: 640.2177028656006s
# [23, 500] loss: 0.0019, e-loss: 0.0013, Correct Rate: 99.60%
# Correctness on training epoch: 99.60%
# Accuracy of the network on the 10000 validation images: 97.85%
# Accuracy of the network on the 10000 translated images: 83.73%
# Accuracy of the network on the 10000 rotated images: 86.66%
# Finished epoch, cumulative time: 672.5093448162079s
# [24, 500] loss: 0.0020, e-loss: 0.0013, Correct Rate: 99.58%
# Correctness on training epoch: 99.58%
# Accuracy of the network on the 10000 validation images: 98.22%
# Accuracy of the network on the 10000 translated images: 81.84%
# Accuracy of the network on the 10000 rotated images: 85.74%
# Finished epoch, cumulative time: 701.444418668747s
# [25, 500] loss: 0.0018, e-loss: 0.0012, Correct Rate: 99.74%
# Correctness on training epoch: 99.74%
# Accuracy of the network on the 10000 validation images: 98.39%
# Accuracy of the network on the 10000 translated images: 83.33%
# Accuracy of the network on the 10000 rotated images: 86.75%
# Finished epoch, cumulative time: 728.8625981807709s
# [26, 500] loss: 0.0014, e-loss: 0.0010, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 83.48%
# Accuracy of the network on the 10000 rotated images: 86.86%
# Finished epoch, cumulative time: 756.1865589618683s
# [27, 500] loss: 0.0012, e-loss: 0.0009, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.45%
# Accuracy of the network on the 10000 translated images: 83.78%
# Accuracy of the network on the 10000 rotated images: 86.73%
# Finished epoch, cumulative time: 783.7248814105988s
# [28, 500] loss: 0.0012, e-loss: 0.0007, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.67%
# Accuracy of the network on the 10000 translated images: 83.98%
# Accuracy of the network on the 10000 rotated images: 87.28%
# Finished epoch, cumulative time: 810.8699879646301s
# [29, 500] loss: 0.0013, e-loss: 0.0008, Correct Rate: 99.75%
# Correctness on training epoch: 99.75%
# Accuracy of the network on the 10000 validation images: 98.56%
# Accuracy of the network on the 10000 translated images: 84.10%
# Accuracy of the network on the 10000 rotated images: 87.28%
# Finished epoch, cumulative time: 838.1461119651794s
# [30, 500] loss: 0.0015, e-loss: 0.0009, Correct Rate: 99.68%
# Correctness on training epoch: 99.68%
# Accuracy of the network on the 10000 validation images: 98.48%
# Accuracy of the network on the 10000 translated images: 84.83%
# Accuracy of the network on the 10000 rotated images: 87.82%
# Finished epoch, cumulative time: 865.5447916984558s
# [31, 500] loss: 0.0013, e-loss: 0.0010, Correct Rate: 99.80%
# Correctness on training epoch: 99.80%
# Accuracy of the network on the 10000 validation images: 98.86%
# Accuracy of the network on the 10000 translated images: 85.80%
# Accuracy of the network on the 10000 rotated images: 88.71%
# Finished epoch, cumulative time: 892.765971660614s
# [32, 500] loss: 0.0010, e-loss: 0.0008, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 86.22%
# Accuracy of the network on the 10000 rotated images: 88.91%
# Finished epoch, cumulative time: 919.9641938209534s
# [33, 500] loss: 0.0009, e-loss: 0.0006, Correct Rate: 99.93%
# Correctness on training epoch: 99.93%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 84.87%
# Accuracy of the network on the 10000 rotated images: 87.98%
# Finished epoch, cumulative time: 947.6318230628967s
# [34, 500] loss: 0.0008, e-loss: 0.0006, Correct Rate: 99.94%
# Correctness on training epoch: 99.94%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 85.71%
# Accuracy of the network on the 10000 rotated images: 88.28%
# Finished epoch, cumulative time: 975.6292104721069s
# [35, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.73%
# Accuracy of the network on the 10000 translated images: 85.16%
# Accuracy of the network on the 10000 rotated images: 87.95%
# Finished epoch, cumulative time: 1003.2865288257599s
# [36, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.92%
# Correctness on training epoch: 99.92%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 85.29%
# Accuracy of the network on the 10000 rotated images: 88.23%
# Finished epoch, cumulative time: 1031.0838069915771s
# [37, 500] loss: 0.0006, e-loss: 0.0005, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.84%
# Accuracy of the network on the 10000 translated images: 86.41%
# Accuracy of the network on the 10000 rotated images: 88.87%
# Finished epoch, cumulative time: 1058.4017264842987s
# [38, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 99.98%
# Correctness on training epoch: 99.98%
# Accuracy of the network on the 10000 validation images: 98.71%
# Accuracy of the network on the 10000 translated images: 86.39%
# Accuracy of the network on the 10000 rotated images: 88.83%
# Finished epoch, cumulative time: 1085.7801983356476s
# [39, 500] loss: 0.0009, e-loss: 0.0004, Correct Rate: 99.77%
# Correctness on training epoch: 99.77%
# Accuracy of the network on the 10000 validation images: 98.67%
# Accuracy of the network on the 10000 translated images: 85.41%
# Accuracy of the network on the 10000 rotated images: 88.04%
# Finished epoch, cumulative time: 1113.1669049263s
# [40, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.94%
# Correctness on training epoch: 99.94%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 85.37%
# Accuracy of the network on the 10000 rotated images: 88.20%
# Finished epoch, cumulative time: 1140.363303899765s
# [41, 500] loss: 0.0006, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.84%
# Accuracy of the network on the 10000 translated images: 85.82%
# Accuracy of the network on the 10000 rotated images: 88.57%
# Finished epoch, cumulative time: 1167.7899420261383s
# [42, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 99.97%
# Correctness on training epoch: 99.97%
# Accuracy of the network on the 10000 validation images: 98.90%
# Accuracy of the network on the 10000 translated images: 86.42%
# Accuracy of the network on the 10000 rotated images: 89.00%
# Finished epoch, cumulative time: 1195.1349365711212s
# [43, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.88%
# Accuracy of the network on the 10000 translated images: 86.93%
# Accuracy of the network on the 10000 rotated images: 89.26%
# Finished epoch, cumulative time: 1223.0083630084991s
# Finished
# [1, 500] loss: 0.0249, e-loss: 0.0087, Correct Rate: 90.16%
# Correctness on training epoch: 90.16%
# Accuracy of the network on the 10000 validation images: 95.53%
# Accuracy of the network on the 10000 translated images: 68.42%
# Accuracy of the network on the 10000 rotated images: 74.75%
# Finished epoch, cumulative time: 27.538394451141357s
# [2, 500] loss: 0.0108, e-loss: 0.0052, Correct Rate: 96.76%
# Correctness on training epoch: 96.76%
# Accuracy of the network on the 10000 validation images: 97.54%
# Accuracy of the network on the 10000 translated images: 72.30%
# Accuracy of the network on the 10000 rotated images: 78.64%
# Finished epoch, cumulative time: 55.80675792694092s
# [3, 500] loss: 0.0097, e-loss: 0.0048, Correct Rate: 96.94%
# Correctness on training epoch: 96.94%
# Accuracy of the network on the 10000 validation images: 96.34%
# Accuracy of the network on the 10000 translated images: 71.66%
# Accuracy of the network on the 10000 rotated images: 77.40%
# Finished epoch, cumulative time: 83.0399878025055s
# [4, 500] loss: 0.0083, e-loss: 0.0044, Correct Rate: 97.57%
# Correctness on training epoch: 97.57%
# Accuracy of the network on the 10000 validation images: 97.76%
# Accuracy of the network on the 10000 translated images: 75.16%
# Accuracy of the network on the 10000 rotated images: 80.86%
# Finished epoch, cumulative time: 110.55861282348633s
# [5, 500] loss: 0.0076, e-loss: 0.0041, Correct Rate: 97.68%
# Correctness on training epoch: 97.68%
# Accuracy of the network on the 10000 validation images: 97.49%
# Accuracy of the network on the 10000 translated images: 74.42%
# Accuracy of the network on the 10000 rotated images: 80.35%
# Finished epoch, cumulative time: 137.97517371177673s
# [6, 500] loss: 0.0070, e-loss: 0.0039, Correct Rate: 98.01%
# Correctness on training epoch: 98.01%
# Accuracy of the network on the 10000 validation images: 95.99%
# Accuracy of the network on the 10000 translated images: 73.62%
# Accuracy of the network on the 10000 rotated images: 78.53%
# Finished epoch, cumulative time: 165.44185328483582s
# [7, 500] loss: 0.0065, e-loss: 0.0037, Correct Rate: 98.31%
# Correctness on training epoch: 98.31%
# Accuracy of the network on the 10000 validation images: 97.91%
# Accuracy of the network on the 10000 translated images: 75.80%
# Accuracy of the network on the 10000 rotated images: 81.34%
# Finished epoch, cumulative time: 192.7168698310852s
# [8, 500] loss: 0.0061, e-loss: 0.0034, Correct Rate: 98.39%
# Correctness on training epoch: 98.39%
# Accuracy of the network on the 10000 validation images: 97.49%
# Accuracy of the network on the 10000 translated images: 76.75%
# Accuracy of the network on the 10000 rotated images: 81.70%
# Finished epoch, cumulative time: 220.1564359664917s
# [9, 500] loss: 0.0060, e-loss: 0.0033, Correct Rate: 98.51%
# Correctness on training epoch: 98.51%
# Accuracy of the network on the 10000 validation images: 98.27%
# Accuracy of the network on the 10000 translated images: 77.25%
# Accuracy of the network on the 10000 rotated images: 82.68%
# Finished epoch, cumulative time: 247.6411988735199s
# [10, 500] loss: 0.0053, e-loss: 0.0031, Correct Rate: 98.54%
# Correctness on training epoch: 98.54%
# Accuracy of the network on the 10000 validation images: 98.48%
# Accuracy of the network on the 10000 translated images: 79.36%
# Accuracy of the network on the 10000 rotated images: 83.99%
# Finished epoch, cumulative time: 274.84410309791565s
# [11, 500] loss: 0.0048, e-loss: 0.0029, Correct Rate: 98.78%
# Correctness on training epoch: 98.78%
# Accuracy of the network on the 10000 validation images: 97.33%
# Accuracy of the network on the 10000 translated images: 77.00%
# Accuracy of the network on the 10000 rotated images: 82.08%
# Finished epoch, cumulative time: 302.13328433036804s
# [12, 500] loss: 0.0047, e-loss: 0.0028, Correct Rate: 98.82%
# Correctness on training epoch: 98.82%
# Accuracy of the network on the 10000 validation images: 97.73%
# Accuracy of the network on the 10000 translated images: 77.39%
# Accuracy of the network on the 10000 rotated images: 81.93%
# Finished epoch, cumulative time: 329.4303352832794s
# [13, 500] loss: 0.0042, e-loss: 0.0026, Correct Rate: 98.95%
# Correctness on training epoch: 98.95%
# Accuracy of the network on the 10000 validation images: 96.36%
# Accuracy of the network on the 10000 translated images: 77.97%
# Accuracy of the network on the 10000 rotated images: 81.77%
# Finished epoch, cumulative time: 355.64286732673645s
# [14, 500] loss: 0.0040, e-loss: 0.0025, Correct Rate: 99.09%
# Correctness on training epoch: 99.09%
# Accuracy of the network on the 10000 validation images: 97.83%
# Accuracy of the network on the 10000 translated images: 78.90%
# Accuracy of the network on the 10000 rotated images: 83.49%
# Finished epoch, cumulative time: 381.7512581348419s
# [15, 500] loss: 0.0037, e-loss: 0.0023, Correct Rate: 99.11%
# Correctness on training epoch: 99.11%
# Accuracy of the network on the 10000 validation images: 98.39%
# Accuracy of the network on the 10000 translated images: 80.78%
# Accuracy of the network on the 10000 rotated images: 84.75%
# Finished epoch, cumulative time: 407.860454082489s
# [16, 500] loss: 0.0035, e-loss: 0.0023, Correct Rate: 99.29%
# Correctness on training epoch: 99.29%
# Accuracy of the network on the 10000 validation images: 97.70%
# Accuracy of the network on the 10000 translated images: 79.92%
# Accuracy of the network on the 10000 rotated images: 84.02%
# Finished epoch, cumulative time: 433.81505155563354s
# [17, 500] loss: 0.0032, e-loss: 0.0021, Correct Rate: 99.37%
# Correctness on training epoch: 99.37%
# Accuracy of the network on the 10000 validation images: 97.79%
# Accuracy of the network on the 10000 translated images: 79.85%
# Accuracy of the network on the 10000 rotated images: 84.14%
# Finished epoch, cumulative time: 459.6620497703552s
# [18, 500] loss: 0.0033, e-loss: 0.0020, Correct Rate: 99.15%
# Correctness on training epoch: 99.15%
# Accuracy of the network on the 10000 validation images: 97.82%
# Accuracy of the network on the 10000 translated images: 79.95%
# Accuracy of the network on the 10000 rotated images: 84.05%
# Finished epoch, cumulative time: 488.4559545516968s
# [19, 500] loss: 0.0030, e-loss: 0.0019, Correct Rate: 99.39%
# Correctness on training epoch: 99.39%
# Accuracy of the network on the 10000 validation images: 98.53%
# Accuracy of the network on the 10000 translated images: 81.39%
# Accuracy of the network on the 10000 rotated images: 85.55%
# Finished epoch, cumulative time: 517.2028059959412s
# [20, 500] loss: 0.0025, e-loss: 0.0017, Correct Rate: 99.53%
# Correctness on training epoch: 99.53%
# Accuracy of the network on the 10000 validation images: 98.03%
# Accuracy of the network on the 10000 translated images: 82.31%
# Accuracy of the network on the 10000 rotated images: 85.57%
# Finished epoch, cumulative time: 544.6404709815979s
# [21, 500] loss: 0.0026, e-loss: 0.0016, Correct Rate: 99.40%
# Correctness on training epoch: 99.40%
# Accuracy of the network on the 10000 validation images: 98.46%
# Accuracy of the network on the 10000 translated images: 81.67%
# Accuracy of the network on the 10000 rotated images: 85.40%
# Finished epoch, cumulative time: 572.6535148620605s
# [22, 500] loss: 0.0024, e-loss: 0.0015, Correct Rate: 99.50%
# Correctness on training epoch: 99.50%
# Accuracy of the network on the 10000 validation images: 98.06%
# Accuracy of the network on the 10000 translated images: 82.70%
# Accuracy of the network on the 10000 rotated images: 86.13%
# Finished epoch, cumulative time: 599.6763386726379s
# [23, 500] loss: 0.0022, e-loss: 0.0015, Correct Rate: 99.58%
# Correctness on training epoch: 99.58%
# Accuracy of the network on the 10000 validation images: 97.59%
# Accuracy of the network on the 10000 translated images: 80.21%
# Accuracy of the network on the 10000 rotated images: 84.06%
# Finished epoch, cumulative time: 626.7648966312408s
# [24, 500] loss: 0.0021, e-loss: 0.0014, Correct Rate: 99.61%
# Correctness on training epoch: 99.61%
# Accuracy of the network on the 10000 validation images: 98.53%
# Accuracy of the network on the 10000 translated images: 82.96%
# Accuracy of the network on the 10000 rotated images: 86.45%
# Finished epoch, cumulative time: 653.9992592334747s
# [25, 500] loss: 0.0018, e-loss: 0.0013, Correct Rate: 99.71%
# Correctness on training epoch: 99.71%
# Accuracy of the network on the 10000 validation images: 98.37%
# Accuracy of the network on the 10000 translated images: 82.46%
# Accuracy of the network on the 10000 rotated images: 85.81%
# Finished epoch, cumulative time: 682.0556991100311s
# [26, 500] loss: 0.0015, e-loss: 0.0010, Correct Rate: 99.79%
# Correctness on training epoch: 99.79%
# Accuracy of the network on the 10000 validation images: 97.97%
# Accuracy of the network on the 10000 translated images: 81.38%
# Accuracy of the network on the 10000 rotated images: 84.73%
# Finished epoch, cumulative time: 709.9552855491638s
# [27, 500] loss: 0.0017, e-loss: 0.0011, Correct Rate: 99.68%
# Correctness on training epoch: 99.68%
# Accuracy of the network on the 10000 validation images: 98.70%
# Accuracy of the network on the 10000 translated images: 82.92%
# Accuracy of the network on the 10000 rotated images: 86.39%
# Finished epoch, cumulative time: 737.940486907959s
# [28, 500] loss: 0.0018, e-loss: 0.0011, Correct Rate: 99.65%
# Correctness on training epoch: 99.65%
# Accuracy of the network on the 10000 validation images: 98.34%
# Accuracy of the network on the 10000 translated images: 82.97%
# Accuracy of the network on the 10000 rotated images: 86.21%
# Finished epoch, cumulative time: 765.7921521663666s
# [29, 500] loss: 0.0016, e-loss: 0.0010, Correct Rate: 99.70%
# Correctness on training epoch: 99.70%
# Accuracy of the network on the 10000 validation images: 98.85%
# Accuracy of the network on the 10000 translated images: 83.93%
# Accuracy of the network on the 10000 rotated images: 87.37%
# Finished epoch, cumulative time: 793.7975716590881s
# [30, 500] loss: 0.0011, e-loss: 0.0009, Correct Rate: 99.89%
# Correctness on training epoch: 99.89%
# Accuracy of the network on the 10000 validation images: 98.71%
# Accuracy of the network on the 10000 translated images: 83.71%
# Accuracy of the network on the 10000 rotated images: 87.30%
# Finished epoch, cumulative time: 821.9315452575684s
# [31, 500] loss: 0.0009, e-loss: 0.0007, Correct Rate: 99.95%
# Correctness on training epoch: 99.95%
# Accuracy of the network on the 10000 validation images: 98.79%
# Accuracy of the network on the 10000 translated images: 84.40%
# Accuracy of the network on the 10000 rotated images: 87.51%
# Finished epoch, cumulative time: 849.4273474216461s
# [32, 500] loss: 0.0008, e-loss: 0.0006, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.56%
# Accuracy of the network on the 10000 translated images: 83.75%
# Accuracy of the network on the 10000 rotated images: 87.07%
# Finished epoch, cumulative time: 877.0400304794312s
# [33, 500] loss: 0.0010, e-loss: 0.0006, Correct Rate: 99.81%
# Correctness on training epoch: 99.81%
# Accuracy of the network on the 10000 validation images: 98.40%
# Accuracy of the network on the 10000 translated images: 81.99%
# Accuracy of the network on the 10000 rotated images: 85.52%
# Finished epoch, cumulative time: 904.5714313983917s
# [34, 500] loss: 0.0014, e-loss: 0.0008, Correct Rate: 99.73%
# Correctness on training epoch: 99.73%
# Accuracy of the network on the 10000 validation images: 98.60%
# Accuracy of the network on the 10000 translated images: 83.70%
# Accuracy of the network on the 10000 rotated images: 87.16%
# Finished epoch, cumulative time: 932.0819075107574s
# [35, 500] loss: 0.0009, e-loss: 0.0007, Correct Rate: 99.94%
# Correctness on training epoch: 99.94%
# Accuracy of the network on the 10000 validation images: 98.93%
# Accuracy of the network on the 10000 translated images: 84.90%
# Accuracy of the network on the 10000 rotated images: 87.96%
# Finished epoch, cumulative time: 959.6465964317322s
# [36, 500] loss: 0.0007, e-loss: 0.0006, Correct Rate: 99.98%
# Correctness on training epoch: 99.98%
# Accuracy of the network on the 10000 validation images: 98.71%
# Accuracy of the network on the 10000 translated images: 83.59%
# Accuracy of the network on the 10000 rotated images: 86.93%
# Finished epoch, cumulative time: 987.3135995864868s
# [37, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.57%
# Accuracy of the network on the 10000 translated images: 84.00%
# Accuracy of the network on the 10000 rotated images: 87.28%
# Finished epoch, cumulative time: 1015.2149729728699s
# [38, 500] loss: 0.0008, e-loss: 0.0006, Correct Rate: 99.88%
# Correctness on training epoch: 99.88%
# Accuracy of the network on the 10000 validation images: 98.66%
# Accuracy of the network on the 10000 translated images: 84.30%
# Accuracy of the network on the 10000 rotated images: 87.41%
# Finished epoch, cumulative time: 1043.6519672870636s
# [39, 500] loss: 0.0008, e-loss: 0.0006, Correct Rate: 99.91%
# Correctness on training epoch: 99.91%
# Accuracy of the network on the 10000 validation images: 98.69%
# Accuracy of the network on the 10000 translated images: 85.05%
# Accuracy of the network on the 10000 rotated images: 87.76%
# Finished epoch, cumulative time: 1071.4008815288544s
# [40, 500] loss: 0.0007, e-loss: 0.0005, Correct Rate: 99.90%
# Correctness on training epoch: 99.90%
# Accuracy of the network on the 10000 validation images: 98.48%
# Accuracy of the network on the 10000 translated images: 84.76%
# Accuracy of the network on the 10000 rotated images: 87.33%
# Finished epoch, cumulative time: 1098.9294016361237s
# [41, 500] loss: 0.0008, e-loss: 0.0005, Correct Rate: 99.90%
# Correctness on training epoch: 99.90%
# Accuracy of the network on the 10000 validation images: 98.74%
# Accuracy of the network on the 10000 translated images: 84.81%
# Accuracy of the network on the 10000 rotated images: 87.84%
# Finished epoch, cumulative time: 1126.6093361377716s
# [42, 500] loss: 0.0006, e-loss: 0.0005, Correct Rate: 99.99%
# Correctness on training epoch: 99.99%
# Accuracy of the network on the 10000 validation images: 98.82%
# Accuracy of the network on the 10000 translated images: 84.91%
# Accuracy of the network on the 10000 rotated images: 87.91%
# Finished epoch, cumulative time: 1154.1273820400238s
# [43, 500] loss: 0.0005, e-loss: 0.0004, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.78%
# Accuracy of the network on the 10000 translated images: 85.06%
# Accuracy of the network on the 10000 rotated images: 88.02%
# Finished epoch, cumulative time: 1181.6089103221893s
# [44, 500] loss: 0.0004, e-loss: 0.0003, Correct Rate: 100.00%
# Correctness on training epoch: 100.00%
# Accuracy of the network on the 10000 validation images: 98.77%
# Accuracy of the network on the 10000 translated images: 84.69%
# Accuracy of the network on the 10000 rotated images: 87.69%
# Finished epoch, cumulative time: 1209.2300441265106s
# Finished
# Allowing Windows to go to sleep
